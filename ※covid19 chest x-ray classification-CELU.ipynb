# %% [markdown]
# # 파일경로 불러오기

# %%
import os

# %%
#normal이라는 directory하위에 있는 모든 이미지들을 list형태로 반환한다.
IMAGE_FORMAT = ["jpeg", 'jpg', 'png']

def list_image_files(data_dir, sub_dir):
    image_files = []
    images_dir = os.path.join(data_dir, sub_dir)
    for file_path in os.listdir(images_dir):
        if file_path.split(".")[-1] in IMAGE_FORMAT:
            image_files.append(os.path.join(sub_dir, file_path))
    return image_files

# %%
data_dir = 'D:/covid/train/'

normals_list = list_image_files(data_dir, 'normal')
covids_list = list_image_files(data_dir, 'covid')
print(f"Normal:{len(normals_list)}, Covid:{len(covids_list)}")
# Out:
# Normal:3022, Covid:2084

# %%
normals_list
# Out:
# ['normal\\00000011_001.png',
#  'normal\\00000011_002.png',
#  'normal\\00000011_003.png',
#  'normal\\00000011_004.png',
#  'normal\\00000011_008.png',
#  'normal\\00000013_014.png',
#  'normal\\00000013_015.png',
#  'normal\\00000013_016.png',
#  'normal\\00000013_017.png',
#  'normal\\00000013_019.png',
#  'normal\\00000013_038.png',
#  'normal\\00000014_000.png',
#  'normal\\00000016_000.png',
#  'normal\\00000018_000.png',
#  'normal\\00000022_000.png',
#  'normal\\00000023_000.png',
#  'normal\\00000023_003.png',
#  'normal\\00000029_000.png',
#  'normal\\00000031_000.png',
#  'normal\\00000034_001.png',
#  'normal\\00000035_000.png',
#  'normal\\00000035_001.png',
#  'normal\\00000037_000.png',
#  'normal\\00000038_002.png',
#  'normal\\00000038_005.png',
#  'normal\\00000038_007.png',
#  'normal\\00000039_000.png',
#  'normal\\00000039_001.png',
#  'normal\\00000039_003.png',
#  'normal\\00000040_000.png',
#  'normal\\00000041_003.png',
#  'normal\\00000041_004.png',
#  'normal\\00000042_005.png',
#  'normal\\00000042_007.png',
#  'normal\\00000047_000.png',
#  'normal\\00000047_001.png',
#  'normal\\00000047_002.png',
#  'normal\\00000047_007.png',
#  'normal\\00000048_000.png',
#  'normal\\00000049_001.png',
#  'normal\\00000049_002.png',
#  'normal\\00000050_001.png',
#  'normal\\00000050_002.png',
#  'normal\\00000050_003.png',
#  'normal\\00000052_000.png',
#  'normal\\00000052_001.png',
#  'normal\\00000054_001.png',
#  'normal\\00000054_002.png',
#  'normal\\00000054_003.png',
#  'normal\\00000054_004.png',
#  'normal\\00000054_005.png',
#  'normal\\00000054_007.png',
#  'normal\\00000054_008.png',
#  'normal\\00000054_009.png',
#  'normal\\00000055_000.png',
#  'normal\\00000057_000.png',
#  'normal\\00000057_003.png',
#  'normal\\00000059_000.png',
#  'normal\\00000059_001.png',
#  'normal\\00000064_000.png',
#  'normal\\00000065_000.png',
#  'normal\\00000067_002.png',
#  'normal\\00000068_000.png',
#  'normal\\00000070_000.png',
#  'normal\\00000071_003.png',
#  'normal\\00000073_000.png',
#  'normal\\00000073_001.png',
#  'normal\\00000073_003.png',
#  'normal\\00000073_004.png',
#  'normal\\00000073_005.png',
#  'normal\\00000073_006.png',
#  'normal\\00000073_007.png',
#  'normal\\00000073_008.png',
#  'normal\\00000073_009.png',
#  'normal\\00000078_000.png',
#  'normal\\00000080_000.png',
#  'normal\\00000080_002.png',
#  'normal\\00000080_005.png',
#  'normal\\00000081_000.png',
#  'normal\\00000082_000.png',
#  'normal\\00000083_000.png',
#  'normal\\00000085_000.png',
#  'normal\\00000086_000.png',
#  'normal\\00000087_001.png',
#  'normal\\00000090_000.png',
#  'normal\\00000090_006.png',
#  'normal\\00000090_010.png',
#  'normal\\00000091_000.png',
#  'normal\\00000091_006.png',
#  'normal\\00000093_002.png',
#  'normal\\00000095_000.png',
#  'normal\\00000096_008.png',
#  'normal\\00000170_000.png',
#  'normal\\00000171_000.png',
#  'normal\\00000172_000.png',
#  'normal\\00000172_001.png',
#  'normal\\00000172_002.png',
#  'normal\\00000172_003.png',
#  'normal\\00000172_004.png',
#  'normal\\00000172_005.png',
#  'normal\\00000172_006.png',
#  'normal\\00000173_001.png',
#  'normal\\00000174_000.png',
#  'normal\\00000174_003.png',
#  'normal\\00000174_004.png',
#  'normal\\00000175_000.png',
#  'normal\\00000176_000.png',
#  'normal\\00000177_000.png',
#  'normal\\00000177_001.png',
#  'normal\\00000177_002.png',
#  'normal\\00000177_003.png',
#  'normal\\00000177_004.png',
#  'normal\\00000177_005.png',
#  'normal\\00000180_001.png',
#  'normal\\00000181_000.png',
#  'normal\\00000181_056.png',
#  'normal\\00000181_057.png',
#  'normal\\00000182_000.png',
#  'normal\\00000183_001.png',
#  'normal\\00000184_000.png',
#  'normal\\00000184_001.png',
#  'normal\\00000186_000.png',
#  'normal\\00000187_001.png',
#  'normal\\00000187_002.png',
#  'normal\\00000188_000.png',
#  'normal\\00000188_001.png',
#  'normal\\00000190_000.png',
#  'normal\\00000190_001.png',
#  'normal\\00000190_002.png',
#  'normal\\00000190_003.png',
#  'normal\\00000190_004.png',
#  'normal\\00000190_005.png',
#  'normal\\00000191_000.png',
#  'normal\\00000192_000.png',
#  'normal\\00000194_000.png',
#  'normal\\00000194_001.png',
#  'normal\\00000194_002.png',
#  'normal\\00000194_003.png',
#  'normal\\00000194_004.png',
#  'normal\\00000194_005.png',
#  'normal\\00000195_000.png',
#  'normal\\00000196_000.png',
#  'normal\\00000197_000.png',
#  'normal\\00000197_001.png',
#  'normal\\00000197_002.png',
#  'normal\\00000197_003.png',
#  'normal\\00000198_000.png',
#  'normal\\00000199_000.png',
#  'normal\\00000199_003.png',
#  'normal\\00000201_000.png',
#  'normal\\00000204_003.png',
#  'normal\\00000205_000.png',
#  'normal\\00000206_000.png',
#  'normal\\00000206_001.png',
#  'normal\\00000207_000.png',
#  'normal\\00000209_000.png',
#  'normal\\00000211_003.png',
#  'normal\\00000211_020.png',
#  'normal\\00000211_030.png',
#  'normal\\00000211_033.png',
#  'normal\\00000211_036.png',
#  'normal\\00000213_000.png',
#  'normal\\00000213_001.png',
#  'normal\\00000213_005.png',
#  'normal\\00000214_000.png',
#  'normal\\00000217_000.png',
#  'normal\\00000218_002.png',
#  'normal\\00000218_003.png',
#  'normal\\00000218_007.png',
#  'normal\\00000218_008.png',
#  'normal\\00000219_002.png',
#  'normal\\00000219_003.png',
#  'normal\\00000220_000.png',
#  'normal\\00000222_000.png',
#  'normal\\00000223_000.png',
#  'normal\\00000225_000.png',
#  'normal\\00000225_001.png',
#  'normal\\00000226_000.png',
#  'normal\\00000227_000.png',
#  'normal\\00000227_001.png',
#  'normal\\00000228_000.png',
#  'normal\\00000229_000.png',
#  'normal\\00000230_000.png',
#  'normal\\00000231_005.png',
#  'normal\\00000231_007.png',
#  'normal\\00000231_008.png',
#  'normal\\00000231_010.png',
#  'normal\\00000231_012.png',
#  'normal\\00000231_013.png',
#  'normal\\00000237_000.png',
#  'normal\\00000238_001.png',
#  'normal\\00000239_000.png',
#  'normal\\00000239_001.png',
#  'normal\\00000239_003.png',
#  'normal\\00000239_004.png',
#  'normal\\00000239_005.png',
#  'normal\\00000241_000.png',
#  'normal\\00000241_001.png',
#  'normal\\00000242_001.png',
#  'normal\\00000242_002.png',
#  'normal\\00000242_003.png',
#  'normal\\00000242_004.png',
#  'normal\\00000243_000.png',
#  'normal\\00000246_000.png',
#  'normal\\00000246_002.png',
#  'normal\\00000246_009.png',
#  'normal\\00000246_018.png',
#  'normal\\00000246_019.png',
#  'normal\\00000248_012.png',
#  'normal\\00000248_025.png',
#  'normal\\00000248_026.png',
#  'normal\\00000249_000.png',
#  'normal\\00000250_000.png',
#  'normal\\00000250_002.png',
#  'normal\\00000250_011.png',
#  'normal\\00000252_000.png',
#  'normal\\00000252_001.png',
#  'normal\\00000253_000.png',
#  'normal\\00000255_000.png',
#  'normal\\00000257_000.png',
#  'normal\\00000259_000.png',
#  'normal\\00000262_000.png',
#  'normal\\00000264_000.png',
#  'normal\\00000265_000.png',
#  'normal\\00000265_001.png',
#  'normal\\00000265_002.png',
#  'normal\\00000265_003.png',
#  'normal\\00000265_004.png',
#  'normal\\00000265_005.png',
#  'normal\\00000266_000.png',
#  'normal\\00000267_000.png',
#  'normal\\00000269_001.png',
#  'normal\\00000271_001.png',
#  'normal\\00000271_003.png',
#  'normal\\00000272_001.png',
#  'normal\\00000272_002.png',
#  'normal\\00000272_003.png',
#  'normal\\00000272_004.png',
#  'normal\\00000272_005.png',
#  'normal\\00000272_006.png',
#  'normal\\00000273_001.png',
#  'normal\\00000273_004.png',
#  'normal\\00000273_005.png',
#  'normal\\00000273_006.png',
#  'normal\\00000273_007.png',
#  'normal\\00000273_008.png',
#  'normal\\00000273_009.png',
#  'normal\\00000274_001.png',
#  'normal\\00000275_004.png',
#  'normal\\00000277_000.png',
#  'normal\\00000277_002.png',
#  'normal\\00000278_002.png',
#  'normal\\00000278_003.png',
#  'normal\\00000278_004.png',
#  'normal\\00000278_005.png',
#  'normal\\00000278_006.png',
#  'normal\\00000278_007.png',
#  'normal\\00000278_009.png',
#  'normal\\00000279_000.png',
#  'normal\\00000280_000.png',
#  'normal\\00000280_001.png',
#  'normal\\00000281_000.png',
#  'normal\\00000281_001.png',
#  'normal\\00000281_002.png',
#  'normal\\00000282_001.png',
#  'normal\\00000283_000.png',
#  'normal\\00000285_000.png',
#  'normal\\00000285_003.png',
#  'normal\\00000285_004.png',
#  'normal\\00000288_001.png',
#  'normal\\00000288_002.png',
#  'normal\\00000288_003.png',
#  'normal\\00000289_000.png',
#  'normal\\00000289_001.png',
#  'normal\\00000289_002.png',
#  'normal\\00000289_003.png',
#  'normal\\00000289_004.png',
#  'normal\\00000289_005.png',
#  'normal\\00000289_006.png',
#  'normal\\00000290_000.png',
#  'normal\\00000291_000.png',
#  'normal\\00000292_000.png',
#  'normal\\00000293_000.png',
#  'normal\\00000294_001.png',
#  'normal\\00000295_000.png',
#  'normal\\00000296_003.png',
#  'normal\\00000298_000.png',
#  'normal\\00000300_000.png',
#  'normal\\00000301_000.png',
#  'normal\\00000301_001.png',
#  'normal\\00000304_000.png',
#  'normal\\00000304_001.png',
#  'normal\\00000304_002.png',
#  'normal\\00000305_000.png',
#  'normal\\00000310_002.png',
#  'normal\\00000311_001.png',
#  'normal\\00000312_000.png',
#  'normal\\00000312_002.png',
#  'normal\\00000391_005.png',
#  'normal\\00000391_007.png',
#  'normal\\00000391_009.png',
#  'normal\\00000392_000.png',
#  'normal\\00000393_000.png',
#  'normal\\00000394_000.png',
#  'normal\\00000396_000.png',
#  'normal\\00000397_000.png',
#  'normal\\00000398_000.png',
#  'normal\\00000398_004.png',
#  'normal\\00000398_005.png',
#  'normal\\00000399_001.png',
#  'normal\\00000401_000.png',
#  'normal\\00000403_001.png',
#  'normal\\00000405_000.png',
#  'normal\\00000406_001.png',
#  'normal\\00000407_000.png',
#  'normal\\00000408_000.png',
#  'normal\\00000410_001.png',
#  'normal\\00000412_000.png',
#  'normal\\00000412_001.png',
#  'normal\\00000412_002.png',
#  'normal\\00000412_003.png',
#  'normal\\00000413_000.png',
#  'normal\\00000414_000.png',
#  'normal\\00000416_000.png',
#  'normal\\00000417_002.png',
#  'normal\\00000417_003.png',
#  'normal\\00000417_004.png',
#  'normal\\00000418_003.png',
#  'normal\\00000419_000.png',
#  'normal\\00000420_000.png',
#  'normal\\00000420_001.png',
#  'normal\\00000422_000.png',
#  'normal\\00000422_001.png',
#  'normal\\00000422_002.png',
#  'normal\\00000422_003.png',
#  'normal\\00000422_004.png',
#  'normal\\00000422_005.png',
#  'normal\\00000425_000.png',
#  'normal\\00000425_001.png',
#  'normal\\00000426_000.png',
#  'normal\\00000426_002.png',
#  'normal\\00000426_003.png',
#  'normal\\00000427_000.png',
#  'normal\\00000427_001.png',
#  'normal\\00000429_000.png',
#  'normal\\00000429_001.png',
#  'normal\\00000430_000.png',
#  'normal\\00000430_001.png',
#  'normal\\00000430_002.png',
#  'normal\\00000431_001.png',
#  'normal\\00000431_003.png',
#  'normal\\00000433_000.png',
#  'normal\\00000434_000.png',
#  'normal\\00000436_000.png',
#  'normal\\00000437_000.png',
#  'normal\\00000438_000.png',
#  'normal\\00000439_000.png',
#  'normal\\00000440_000.png',
#  'normal\\00000440_001.png',
#  'normal\\00000443_000.png',
#  'normal\\00000443_002.png',
#  'normal\\00000443_003.png',
#  'normal\\00000444_003.png',
#  'normal\\00000445_000.png',
#  'normal\\00000446_001.png',
#  'normal\\00000447_000.png',
#  'normal\\00000447_001.png',
#  'normal\\00000447_002.png',
#  'normal\\00000447_003.png',
#  'normal\\00000447_004.png',
#  'normal\\00000448_001.png',
#  'normal\\00000449_000.png',
#  'normal\\00000449_001.png',
#  'normal\\00000449_002.png',
#  'normal\\00000449_003.png',
#  'normal\\00000450_007.png',
#  'normal\\00000452_000.png',
#  'normal\\00000453_000.png',
#  'normal\\00000454_000.png',
#  'normal\\00000455_000.png',
#  'normal\\00000456_000.png',
#  'normal\\00000456_001.png',
#  'normal\\00000457_000.png',
#  'normal\\00000458_000.png',
#  'normal\\00000458_002.png',
#  'normal\\00000459_002.png',
#  'normal\\00000459_006.png',
#  'normal\\00000459_009.png',
#  'normal\\00000459_012.png',
#  'normal\\00000459_013.png',
#  'normal\\00000459_014.png',
#  'normal\\00000459_015.png',
#  'normal\\00000459_019.png',
#  'normal\\00000459_021.png',
#  'normal\\00000459_023.png',
#  'normal\\00000459_025.png',
#  'normal\\00000459_026.png',
#  'normal\\00000459_028.png',
#  'normal\\00000461_001.png',
#  'normal\\00000461_002.png',
#  'normal\\00000463_000.png',
#  'normal\\00000463_001.png',
#  'normal\\00000464_000.png',
#  'normal\\00000465_001.png',
#  'normal\\00000466_000.png',
#  'normal\\00000466_001.png',
#  'normal\\00000466_002.png',
#  'normal\\00000466_003.png',
#  'normal\\00000466_004.png',
#  'normal\\00000468_038.png',
#  'normal\\00000468_042.png',
#  'normal\\00000468_044.png',
#  'normal\\00000468_048.png',
#  'normal\\00000468_051.png',
#  'normal\\00000468_057.png',
#  'normal\\00000468_059.png',
#  'normal\\00000469_000.png',
#  'normal\\00000469_001.png',
#  'normal\\00000469_002.png',
#  'normal\\00000470_000.png',
#  'normal\\00000472_000.png',
#  'normal\\00000473_000.png',
#  'normal\\00000474_000.png',
#  'normal\\00000475_000.png',
#  'normal\\00000476_000.png',
#  'normal\\00000477_000.png',
#  'normal\\00000478_002.png',
#  'normal\\00000479_000.png',
#  'normal\\00000480_000.png',
#  'normal\\00000481_000.png',
#  'normal\\00000481_001.png',
#  'normal\\00000483_000.png',
#  'normal\\00000484_000.png',
#  'normal\\00000486_000.png',
#  'normal\\00000486_001.png',
#  'normal\\00000486_002.png',
#  'normal\\00000486_003.png',
#  'normal\\00000486_004.png',
#  'normal\\00000491_005.png',
#  'normal\\00000494_001.png',
#  'normal\\00000494_002.png',
#  'normal\\00000494_003.png',
#  'normal\\00000494_004.png',
#  'normal\\00000494_005.png',
#  'normal\\00000494_006.png',
#  'normal\\00000494_007.png',
#  'normal\\00000495_000.png',
#  'normal\\00000497_000.png',
#  'normal\\00000498_000.png',
#  'normal\\00000498_001.png',
#  'normal\\00000498_002.png',
#  'normal\\00000500_000.png',
#  'normal\\00000500_001.png',
#  'normal\\00000500_002.png',
#  'normal\\00000500_003.png',
#  'normal\\00000500_004.png',
#  'normal\\00000500_005.png',
#  'normal\\00000500_006.png',
#  'normal\\00000500_007.png',
#  'normal\\00000500_008.png',
#  'normal\\00000500_009.png',
#  'normal\\00000502_000.png',
#  'normal\\00000502_001.png',
#  'normal\\00000502_014.png',
#  'normal\\00000502_015.png',
#  'normal\\00000504_000.png',
#  'normal\\00000505_000.png',
#  'normal\\00000505_001.png',
#  'normal\\00000506_011.png',
#  'normal\\00000507_000.png',
#  'normal\\00000509_000.png',
#  'normal\\00000509_001.png',
#  'normal\\00000510_000.png',
#  'normal\\00000511_000.png',
#  'normal\\00000511_001.png',
#  'normal\\00000514_000.png',
#  'normal\\00000514_004.png',
#  'normal\\00000514_005.png',
#  'normal\\00000514_006.png',
#  'normal\\00000516_000.png',
#  'normal\\00000517_002.png',
#  'normal\\00000517_003.png',
#  'normal\\00000517_004.png',
#  'normal\\00000517_005.png',
#  'normal\\00000518_000.png',
#  'normal\\00000519_000.png',
#  'normal\\00000520_000.png',
#  'normal\\00000523_000.png',
#  'normal\\00000524_000.png',
#  'normal\\00000525_000.png',
#  'normal\\00000526_000.png',
#  'normal\\00000526_001.png',
#  'normal\\00000527_000.png',
#  'normal\\00000530_000.png',
#  'normal\\00000531_001.png',
#  'normal\\00000531_003.png',
#  'normal\\00000531_004.png',
#  'normal\\00000531_005.png',
#  'normal\\00000531_006.png',
#  'normal\\00000532_000.png',
#  'normal\\00000533_000.png',
#  'normal\\00000533_003.png',
#  'normal\\00000538_000.png',
#  'normal\\00000538_001.png',
#  'normal\\00000538_003.png',
#  'normal\\00000538_004.png',
#  'normal\\00000538_005.png',
#  'normal\\00000539_000.png',
#  'normal\\00000540_000.png',
#  'normal\\00000541_000.png',
#  'normal\\00000541_001.png',
#  'normal\\00000541_002.png',
#  'normal\\00000541_003.png',
#  'normal\\00000541_004.png',
#  'normal\\00000542_000.png',
#  'normal\\00000542_001.png',
#  'normal\\00000543_000.png',
#  'normal\\00000544_000.png',
#  'normal\\00000545_002.png',
#  'normal\\00000545_003.png',
#  'normal\\00000545_005.png',
#  'normal\\00000545_006.png',
#  'normal\\00000545_007.png',
#  'normal\\00000545_008.png',
#  'normal\\00000545_010.png',
#  'normal\\00000624_005.png',
#  'normal\\00000624_006.png',
#  'normal\\00000625_001.png',
#  'normal\\00000626_000.png',
#  'normal\\00000627_020.png',
#  'normal\\00000628_000.png',
#  'normal\\00000628_002.png',
#  'normal\\00000630_000.png',
#  'normal\\00000631_000.png',
#  'normal\\00000631_006.png',
#  'normal\\00000631_007.png',
#  'normal\\00000632_000.png',
#  'normal\\00000632_002.png',
#  'normal\\00000632_003.png',
#  'normal\\00000632_004.png',
#  'normal\\00000632_005.png',
#  'normal\\00000632_006.png',
#  'normal\\00000632_012.png',
#  'normal\\00000633_000.png',
#  'normal\\00000633_001.png',
#  'normal\\00000634_002.png',
#  'normal\\00000634_005.png',
#  'normal\\00000634_006.png',
#  'normal\\00000634_007.png',
#  'normal\\00000634_008.png',
#  'normal\\00000636_000.png',
#  'normal\\00000637_000.png',
#  'normal\\00000638_000.png',
#  'normal\\00000643_000.png',
#  'normal\\00000644_000.png',
#  'normal\\00000644_001.png',
#  'normal\\00000645_000.png',
#  'normal\\00000645_001.png',
#  'normal\\00000646_002.png',
#  'normal\\00000646_003.png',
#  'normal\\00000646_004.png',
#  'normal\\00000646_005.png',
#  'normal\\00000646_007.png',
#  'normal\\00000647_000.png',
#  'normal\\00000648_000.png',
#  'normal\\00000650_000.png',
#  'normal\\00000651_000.png',
#  'normal\\00000652_000.png',
#  'normal\\00000652_001.png',
#  'normal\\00000652_002.png',
#  'normal\\00000652_008.png',
#  'normal\\00000652_011.png',
#  'normal\\00000652_024.png',
#  'normal\\00000653_000.png',
#  'normal\\00000653_001.png',
#  'normal\\00000654_000.png',
#  'normal\\00000654_001.png',
#  'normal\\00000655_006.png',
#  'normal\\00000657_000.png',
#  'normal\\00000659_000.png',
#  'normal\\00000659_001.png',
#  'normal\\00000659_002.png',
#  'normal\\00000660_000.png',
#  'normal\\00000662_000.png',
#  'normal\\00000662_001.png',
#  'normal\\00000662_002.png',
#  'normal\\00000662_003.png',
#  'normal\\00000662_004.png',
#  'normal\\00000662_005.png',
#  'normal\\00000662_006.png',
#  'normal\\00000662_007.png',
#  'normal\\00000662_008.png',
#  'normal\\00000663_000.png',
#  'normal\\00000664_000.png',
#  'normal\\00000665_000.png',
#  'normal\\00000667_000.png',
#  'normal\\00000668_000.png',
#  'normal\\00000669_000.png',
#  'normal\\00000670_000.png',
#  'normal\\00000671_000.png',
#  'normal\\00000673_000.png',
#  'normal\\00000674_000.png',
#  'normal\\00000675_000.png',
#  'normal\\00000676_001.png',
#  'normal\\00000676_003.png',
#  'normal\\00000679_000.png',
#  'normal\\00000681_000.png',
#  'normal\\00000682_000.png',
#  'normal\\00000682_003.png',
#  'normal\\00000682_004.png',
#  'normal\\00000683_000.png',
#  'normal\\00000683_001.png',
#  'normal\\00000683_003.png',
#  'normal\\00000683_005.png',
#  'normal\\00000684_000.png',
#  'normal\\00000685_000.png',
#  'normal\\00000687_000.png',
#  'normal\\00000689_000.png',
#  'normal\\00000690_000.png',
#  'normal\\00000691_000.png',
#  'normal\\00000692_000.png',
#  'normal\\00000694_000.png',
#  'normal\\00000694_001.png',
#  'normal\\00000694_003.png',
#  'normal\\00000696_000.png',
#  'normal\\00000697_000.png',
#  'normal\\00000697_001.png',
#  'normal\\00000697_003.png',
#  'normal\\00000697_004.png',
#  'normal\\00000697_005.png',
#  'normal\\00000697_008.png',
#  'normal\\00000698_000.png',
#  'normal\\00000699_000.png',
#  'normal\\00000699_001.png',
#  'normal\\00000700_000.png',
#  'normal\\00000700_001.png',
#  'normal\\00000701_000.png',
#  'normal\\00000704_000.png',
#  'normal\\00000704_001.png',
#  'normal\\00000704_002.png',
#  'normal\\00000704_003.png',
#  'normal\\00000705_000.png',
#  'normal\\00000705_001.png',
#  'normal\\00000705_002.png',
#  'normal\\00000709_000.png',
#  'normal\\00000709_003.png',
#  'normal\\00000709_004.png',
#  'normal\\00000709_005.png',
#  'normal\\00000709_006.png',
#  'normal\\00000709_007.png',
#  'normal\\00000710_006.png',
#  'normal\\00000712_000.png',
#  'normal\\00000712_001.png',
#  'normal\\00000714_000.png',
#  'normal\\00000715_000.png',
#  'normal\\00000715_001.png',
#  'normal\\00000716_001.png',
#  'normal\\00000716_002.png',
#  'normal\\00000716_003.png',
#  'normal\\00000717_000.png',
#  'normal\\00000718_000.png',
#  'normal\\00000720_000.png',
#  'normal\\00000720_001.png',
#  'normal\\00000721_001.png',
#  'normal\\00000722_000.png',
#  'normal\\00000723_000.png',
#  'normal\\00000723_001.png',
#  'normal\\00000725_000.png',
#  'normal\\00000726_000.png',
#  'normal\\00000727_001.png',
#  'normal\\00000727_002.png',
#  'normal\\00000727_003.png',
#  'normal\\00000727_005.png',
#  'normal\\00000727_007.png',
#  'normal\\00000727_008.png',
#  'normal\\00000729_000.png',
#  'normal\\00000730_000.png',
#  'normal\\00000731_000.png',
#  'normal\\00000731_001.png',
#  'normal\\00000731_002.png',
#  'normal\\00000731_004.png',
#  'normal\\00000731_005.png',
#  'normal\\00000731_006.png',
#  'normal\\00000731_007.png',
#  'normal\\00000731_008.png',
#  'normal\\00000732_003.png',
#  'normal\\00000732_010.png',
#  'normal\\00000736_000.png',
#  'normal\\00000737_000.png',
#  'normal\\00000738_000.png',
#  'normal\\00000739_000.png',
#  'normal\\00000739_001.png',
#  'normal\\00000741_001.png',
#  'normal\\00000741_002.png',
#  'normal\\00000741_003.png',
#  'normal\\00000741_004.png',
#  'normal\\00000741_005.png',
#  'normal\\00000741_006.png',
#  'normal\\00000741_008.png',
#  'normal\\00000742_003.png',
#  'normal\\00000743_000.png',
#  'normal\\00000743_001.png',
#  'normal\\00000743_002.png',
#  'normal\\00000743_003.png',
#  'normal\\00000744_000.png',
#  'normal\\00000744_013.png',
#  'normal\\00000745_002.png',
#  'normal\\00000746_000.png',
#  'normal\\00000747_000.png',
#  'normal\\00000749_000.png',
#  'normal\\00000750_000.png',
#  'normal\\00000751_000.png',
#  'normal\\00000752_000.png',
#  'normal\\00000752_001.png',
#  'normal\\00000753_000.png',
#  'normal\\00000753_001.png',
#  'normal\\00000754_000.png',
#  'normal\\00000754_006.png',
#  'normal\\00000755_000.png',
#  'normal\\00000756_000.png',
#  'normal\\00000757_000.png',
#  'normal\\00000757_001.png',
#  'normal\\00000757_002.png',
#  'normal\\00000758_000.png',
#  'normal\\00000760_000.png',
#  'normal\\00000761_008.png',
#  'normal\\00000762_000.png',
#  'normal\\00000763_000.png',
#  'normal\\00000764_000.png',
#  'normal\\00000764_001.png',
#  'normal\\00000764_002.png',
#  'normal\\00000765_001.png',
#  'normal\\00000765_002.png',
#  'normal\\00000765_003.png',
#  'normal\\00000765_004.png',
#  'normal\\00000765_005.png',
#  'normal\\00000766_009.png',
#  'normal\\00000767_000.png',
#  'normal\\00000768_000.png',
#  'normal\\00000769_000.png',
#  'normal\\00000770_000.png',
#  'normal\\00000770_001.png',
#  'normal\\00000771_000.png',
#  'normal\\00000772_001.png',
#  'normal\\00000772_004.png',
#  'normal\\00000772_006.png',
#  'normal\\00000772_007.png',
#  'normal\\00000773_000.png',
#  'normal\\00000776_000.png',
#  'normal\\00000777_000.png',
#  'normal\\00000779_001.png',
#  'normal\\00000781_000.png',
#  'normal\\00000781_001.png',
#  'normal\\00000781_003.png',
#  'normal\\00000781_004.png',
#  'normal\\00000781_005.png',
#  'normal\\00000781_006.png',
#  'normal\\00000781_007.png',
#  'normal\\00000781_008.png',
#  'normal\\00000781_009.png',
#  'normal\\00000782_001.png',
#  'normal\\00000782_003.png',
#  'normal\\00000784_000.png',
#  'normal\\00000785_002.png',
#  'normal\\00000786_000.png',
#  'normal\\00000788_000.png',
#  'normal\\00000789_000.png',
#  'normal\\00000791_000.png',
#  'normal\\00000792_000.png',
#  'normal\\00000792_001.png',
#  'normal\\00000793_000.png',
#  'normal\\00000794_000.png',
#  'normal\\00000794_001.png',
#  'normal\\00000795_000.png',
#  'normal\\00000796_000.png',
#  'normal\\00000796_001.png',
#  'normal\\00000796_002.png',
#  'normal\\00000796_003.png',
#  'normal\\00000796_004.png',
#  'normal\\00000796_006.png',
#  'normal\\00000796_007.png',
#  'normal\\00000796_008.png',
#  'normal\\00000798_000.png',
#  'normal\\00000798_002.png',
#  'normal\\00000798_003.png',
#  'normal\\00000798_006.png',
#  'normal\\00000798_007.png',
#  'normal\\00000798_008.png',
#  'normal\\00000802_000.png',
#  'normal\\00000803_000.png',
#  'normal\\00000804_000.png',
#  'normal\\00000805_000.png',
#  'normal\\00000805_001.png',
#  'normal\\00000805_002.png',
#  'normal\\00000805_003.png',
#  'normal\\00000808_004.png',
#  'normal\\00000809_000.png',
#  'normal\\00000809_001.png',
#  'normal\\00000809_002.png',
#  'normal\\00000809_003.png',
#  'normal\\00000809_004.png',
#  'normal\\00000810_000.png',
#  'normal\\00000811_000.png',
#  'normal\\00000812_000.png',
#  'normal\\00000813_000.png',
#  'normal\\00000813_001.png',
#  'normal\\00000814_000.png',
#  'normal\\00000814_003.png',
#  'normal\\00000814_007.png',
#  'normal\\00000815_000.png',
#  'normal\\00000815_002.png',
#  'normal\\00000817_000.png',
#  'normal\\00000817_001.png',
#  'normal\\00000818_000.png',
#  'normal\\00000819_000.png',
#  'normal\\00000820_018.png',
#  'normal\\00000820_020.png',
#  'normal\\00000820_027.png',
#  'normal\\00000821_000.png',
#  'normal\\00000821_001.png',
#  'normal\\00000822_000.png',
#  'normal\\00000823_004.png',
#  'normal\\00000824_000.png',
#  'normal\\00000824_001.png',
#  'normal\\00000825_001.png',
#  'normal\\00000825_004.png',
#  'normal\\00000826_000.png',
#  'normal\\00000827_001.png',
#  'normal\\00000827_013.png',
#  'normal\\00000827_015.png',
#  'normal\\00000829_000.png',
#  'normal\\00000830_005.png',
#  'normal\\00000830_006.png',
#  'normal\\00000832_003.png',
#  'normal\\00000832_007.png',
#  'normal\\00000833_000.png',
#  'normal\\00000833_001.png',
#  'normal\\00000833_002.png',
#  'normal\\00000834_000.png',
#  'normal\\00000834_001.png',
#  'normal\\00000835_000.png',
#  'normal\\00000836_000.png',
#  'normal\\00000838_000.png',
#  'normal\\00000839_000.png',
#  'normal\\00000840_000.png',
#  'normal\\00000841_000.png',
#  'normal\\00000841_001.png',
#  'normal\\00000842_000.png',
#  'normal\\00000843_000.png',
#  'normal\\00000845_002.png',
#  'normal\\00000845_003.png',
#  'normal\\00000846_000.png',
#  'normal\\00000847_000.png',
#  'normal\\00000847_001.png',
#  'normal\\00000850_000.png',
#  'normal\\00000851_000.png',
#  'normal\\00000853_000.png',
#  'normal\\00000853_002.png',
#  'normal\\00000854_000.png',
#  'normal\\00000855_000.png',
#  'normal\\00000857_000.png',
#  'normal\\00000857_002.png',
#  'normal\\00000857_003.png',
#  'normal\\00000857_008.png',
#  'normal\\00000858_000.png',
#  'normal\\00000860_000.png',
#  'normal\\00000860_001.png',
#  'normal\\00000860_002.png',
#  'normal\\00000861_000.png',
#  'normal\\00000914_003.png',
#  'normal\\00000914_004.png',
#  'normal\\00000914_005.png',
#  'normal\\00000916_000.png',
#  'normal\\00000917_000.png',
#  'normal\\00000918_000.png',
#  'normal\\00000919_000.png',
#  'normal\\00000921_000.png',
#  'normal\\00000922_000.png',
#  'normal\\00000922_001.png',
#  'normal\\00000923_000.png',
#  'normal\\00000925_000.png',
#  'normal\\00000926_000.png',
#  'normal\\00000926_002.png',
#  'normal\\00000927_000.png',
#  'normal\\00000927_001.png',
#  'normal\\00000927_002.png',
#  'normal\\00000930_001.png',
#  'normal\\00000930_002.png',
#  'normal\\00000931_000.png',
#  'normal\\00000933_000.png',
#  'normal\\00000935_001.png',
#  'normal\\00000936_000.png',
#  'normal\\00000937_000.png',
#  'normal\\00000937_005.png',
#  'normal\\00000938_000.png',
#  'normal\\00000939_000.png',
#  'normal\\00000940_000.png',
#  'normal\\00000941_000.png',
#  'normal\\00000944_000.png',
#  'normal\\00000946_000.png',
#  'normal\\00000947_000.png',
#  'normal\\00000947_001.png',
#  'normal\\00000947_002.png',
#  'normal\\00000947_003.png',
#  'normal\\00000949_003.png',
#  'normal\\00000949_006.png',
#  'normal\\00000949_008.png',
#  'normal\\00000949_009.png',
#  'normal\\00000951_000.png',
#  'normal\\00000952_000.png',
#  'normal\\00000953_000.png',
#  'normal\\00000954_000.png',
#  'normal\\00000954_007.png',
#  'normal\\00000955_000.png',
#  'normal\\00000955_001.png',
#  'normal\\00000957_000.png',
#  'normal\\00000958_000.png',
#  'normal\\00000960_000.png',
#  'normal\\00000962_000.png',
#  'normal\\00000963_019.png',
#  'normal\\00000963_021.png',
#  'normal\\00000963_022.png',
#  'normal\\00000964_000.png',
#  'normal\\00000965_000.png',
#  'normal\\00000967_001.png',
#  'normal\\00000967_002.png',
#  'normal\\00000969_000.png',
#  'normal\\00000970_000.png',
#  'normal\\00000971_001.png',
#  'normal\\00000971_003.png',
#  'normal\\00000972_000.png',
#  'normal\\00000972_001.png',
#  'normal\\00000972_002.png',
#  'normal\\00000973_000.png',
#  'normal\\00000973_001.png',
#  'normal\\00000974_000.png',
#  'normal\\00000974_001.png',
#  'normal\\00000974_002.png',
#  'normal\\00000974_004.png',
#  'normal\\00000974_005.png',
#  'normal\\00000974_007.png',
#  'normal\\00000974_008.png',
#  'normal\\00000974_009.png',
#  'normal\\00000974_010.png',
#  'normal\\00000975_000.png',
#  'normal\\00000976_000.png',
#  'normal\\00000976_001.png',
#  'normal\\00000976_002.png',
#  'normal\\00000976_003.png',
#  'normal\\00000976_004.png',
#  'normal\\00000976_005.png',
#  'normal\\00000977_000.png',
#  'normal\\00000979_001.png',
#  'normal\\00000979_002.png',
#  'normal\\00000980_000.png',
#  'normal\\00000980_001.png',
#  'normal\\00000980_002.png',
#  'normal\\00000984_000.png',
#  'normal\\00000985_000.png',
#  'normal\\00000987_000.png',
#  'normal\\00000988_001.png',
#  'normal\\00000989_002.png',
#  'normal\\00000991_000.png',
#  'normal\\00000992_001.png',
#  'normal\\00000994_000.png',
#  'normal\\00000995_000.png',
#  'normal\\00000996_000.png',
#  'normal\\00000996_001.png',
#  'normal\\00000996_002.png',
#  'normal\\00000996_003.png',
#  'normal\\00000996_004.png',
#  'normal\\00000996_005.png',
#  'normal\\00000997_000.png',
#  'normal\\00000997_002.png',
#  'normal\\00001000_001.png',
#  'normal\\00001001_000.png',
#  'normal\\00001002_000.png',
#  'normal\\00001003_000.png',
#  'normal\\00001003_001.png',
#  'normal\\00001004_000.png',
#  'normal\\00001004_001.png',
#  'normal\\00001004_002.png',
#  'normal\\00001006_005.png',
#  'normal\\00001006_008.png',
#  'normal\\00001007_000.png',
#  'normal\\00001007_001.png',
#  'normal\\00001007_003.png',
#  'normal\\00001010_000.png',
#  'normal\\00001011_000.png',
#  'normal\\00001011_001.png',
#  'normal\\00001013_000.png',
#  'normal\\00001015_000.png',
#  'normal\\00001016_000.png',
#  'normal\\00001018_000.png',
#  'normal\\00001018_001.png',
#  'normal\\00001018_003.png',
#  'normal\\00001018_007.png',
#  'normal\\00001019_000.png',
#  'normal\\00001019_001.png',
#  'normal\\00001019_003.png',
#  ...]

# %%
covids_list
# Out:
# ['covid\\002.jpeg',
#  'covid\\0021a3ef8340e3c2a599843997e94c76.jpg',
#  'covid\\003.jpeg',
#  'covid\\004.jpeg',
#  'covid\\005.jpeg',
#  'covid\\006.jpeg',
#  'covid\\00960b9bd138047f3b868404aac7e531.jpg',
#  'covid\\010.jpeg',
#  'covid\\010.png',
#  'covid\\0102.jpeg',
#  'covid\\0105.png',
#  'covid\\0106.jpeg',
#  'covid\\0108.jpeg',
#  'covid\\011.jpeg',
#  'covid\\0111.jpg',
#  'covid\\0112.jpg',
#  'covid\\0113.jpg',
#  'covid\\0115.jpeg',
#  'covid\\0118.jpeg',
#  'covid\\0119.jpeg',
#  'covid\\012.jpeg',
#  'covid\\0120.jpg',
#  'covid\\014.jpeg',
#  'covid\\015.jpeg',
#  'covid\\015.jpg',
#  'covid\\016.jpeg',
#  'covid\\017.jpeg',
#  'covid\\018.jpeg',
#  'covid\\0187b7c65ef69abd633c9bad6675dabf.jpg',
#  'covid\\019.jpeg',
#  'covid\\019.png',
#  'covid\\019ba8f463bf79db9875debbf9613b03.jpg',
#  'covid\\02.jpeg',
#  'covid\\020.jpg',
#  'covid\\021.jpeg',
#  'covid\\021.jpg',
#  'covid\\0212b1174ada9d996bf64d78daa46ca3.jpg',
#  'covid\\022.jpeg',
#  'covid\\022.jpg',
#  'covid\\022fd5ca4843bfdc868b0a23541dd15e.jpg',
#  'covid\\024.jpeg',
#  'covid\\024.jpg',
#  'covid\\025.jpeg',
#  'covid\\025.jpg',
#  'covid\\026.jpeg',
#  'covid\\026.jpg',
#  'covid\\027.jpeg',
#  'covid\\027.jpg',
#  'covid\\028.jpg',
#  'covid\\029.jpg',
#  'covid\\03.jpeg',
#  'covid\\031.jpeg',
#  'covid\\031.png',
#  'covid\\032.jpeg',
#  'covid\\033.png',
#  'covid\\038.jpg',
#  'covid\\039.jpeg',
#  'covid\\039.jpg',
#  'covid\\03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C-1068x1083.jpeg',
#  'covid\\03BF7561-A9BA-4C3C-B8A0-D3E585F73F3C.jpeg',
#  'covid\\04.png',
#  'covid\\040.jpeg',
#  'covid\\041.jpeg',
#  'covid\\042.jpeg',
#  'covid\\043.jpeg',
#  'covid\\044.jpeg',
#  'covid\\045.jpeg',
#  'covid\\046.jpeg',
#  'covid\\046.png',
#  'covid\\047.jpeg',
#  'covid\\047.png',
#  'covid\\048.jpeg',
#  'covid\\048.png',
#  'covid\\04865b70ada1e03193d81ebb0da76e22.jpg',
#  'covid\\049.jpeg',
#  'covid\\049.png',
#  'covid\\050.jpeg',
#  'covid\\0502a4ff12d365f32936fed57a264a24.jpg',
#  'covid\\051.jpeg',
#  'covid\\052.jpeg',
#  'covid\\052.png',
#  'covid\\053.jpeg',
#  'covid\\053.png',
#  'covid\\054.jpeg',
#  'covid\\055.jpeg',
#  'covid\\056.jpg',
#  'covid\\057.jpeg',
#  'covid\\058.jpeg',
#  'covid\\05837f70498e9d5e4440258e038b924d.jpg',
#  'covid\\059.jpeg',
#  'covid\\05cb80ddfc72076a014e3040f5cce253.jpg',
#  'covid\\06.jpeg',
#  'covid\\060.jpeg',
#  'covid\\061.jpeg',
#  'covid\\061.jpg',
#  'covid\\062.jpeg',
#  'covid\\063.jpeg',
#  'covid\\06354311ebd38f147d0658499dd6bfc4.jpg',
#  'covid\\064.jpeg',
#  'covid\\06671cc6a8553ccf2313e54fc91ea145.jpg',
#  'covid\\06afa6aafce52c8d4d0fdbe6cc0ca1ba.jpg',
#  'covid\\06c1c008c4145f1abc744071da2259e0.jpg',
#  'covid\\07.jpg',
#  'covid\\07eef010d4bfffb2efdc6e206dbff5f2.jpg',
#  'covid\\08.jpeg',
#  'covid\\0800e279ac2d036bb393ef203ebce44f.jpg',
#  'covid\\0887aa087d7e570c81c88c31aba585e7.jpg',
#  'covid\\09.png',
#  'covid\\0973fbc2ba623c724bce897239e6670c.jpg',
#  'covid\\09a1b8f056217a6c61ab4920609fd0ab.jpg',
#  'covid\\1-s2.0-S1684118220300682-main.pdf-002-a2.png',
#  'covid\\1-s2.0-S1684118220300682-main.pdf-003-b1.png',
#  'covid\\1-s2.0-S1684118220300682-main.pdf-003-b2.png',
#  'covid\\101.jpeg',
#  'covid\\1052b0fe.png',
#  'covid\\109.jpeg',
#  'covid\\10cbb558232726b4ca4f65e9699447d2.jpg',
#  'covid\\10eddd144ca9f07831d6a07e7a0e9465.jpg',
#  'covid\\110.jpeg',
#  'covid\\111.jpeg',
#  'covid\\113.jpeg',
#  'covid\\114.jpeg',
#  'covid\\115.jpeg',
#  'covid\\117.jpeg',
#  'covid\\118.jpeg',
#  'covid\\11bdde9cb7b7ae1478e92cb062ab22f9.jpg',
#  'covid\\11cb02770619172e6cbb0500fd3bba0b.jpg',
#  'covid\\11e9ce2a931e058eb70a97f0375c4355.jpg',
#  'covid\\120.jpeg',
#  'covid\\122.jpeg',
#  'covid\\123.jpeg',
#  'covid\\124.png',
#  'covid\\127.jpg',
#  'covid\\128.jpg',
#  'covid\\12820302d773987bf9ce4d78b6049624.jpg',
#  'covid\\12bd8f797373db45259600ce8e7ad76a.jpg',
#  'covid\\130.jpg',
#  'covid\\131.jpg',
#  'covid\\1312A392-67A3-4EBF-9319-810CF6DA5EF6-1068x1086.jpeg',
#  'covid\\1312A392-67A3-4EBF-9319-810CF6DA5EF6.jpeg',
#  'covid\\132.jpg',
#  'covid\\133.jpg',
#  'covid\\134.jpeg',
#  'covid\\134895D3-77B8-4546-B7E5-C7DABD600309-1068x911.jpeg',
#  'covid\\135.jpeg',
#  'covid\\136.jpeg',
#  'covid\\138.jpeg',
#  'covid\\1380881e07ad7be91719c53e06c5d392.jpg',
#  'covid\\13e54d58a79f4d4c8f2f16cadc3f5b86.jpg',
#  'covid\\140.jpeg',
#  'covid\\141.jpeg',
#  'covid\\147.png',
#  'covid\\148.png',
#  'covid\\14bdd93ad4362a7d4127848d9d37487d.jpg',
#  'covid\\14cba19c79cc386ac43b91d519dd24cd.jpg',
#  'covid\\152.png',
#  'covid\\154.jpeg',
#  'covid\\155.jpeg',
#  'covid\\156.jpg',
#  'covid\\157.jpg',
#  'covid\\158.jpeg',
#  'covid\\159.jpeg',
#  'covid\\160.jpg',
#  'covid\\161.jpg',
#  'covid\\162.jpg',
#  'covid\\163.jpeg',
#  'covid\\164.jpeg',
#  'covid\\165.jpeg',
#  'covid\\166-.jpeg',
#  'covid\\16654_1_1.png',
#  'covid\\16663_1_1.jpg',
#  'covid\\16664_1_1.jpg',
#  'covid\\16674_1_1.jpg',
#  'covid\\16691_1_1.jpg',
#  'covid\\167.png',
#  'covid\\16708_1_1.jpg',
#  'covid\\16724_1_1.jpg',
#  'covid\\168.jpeg',
#  'covid\\16ddffb8e5a07bca99bcf8db4b938322.jpg',
#  'covid\\171.jpeg',
#  'covid\\17bbda86d2291e42eb577c8d4410cb99.jpg',
#  'covid\\180-.jpeg',
#  'covid\\187.jpeg',
#  'covid\\189.jpg',
#  'covid\\190.jpeg',
#  'covid\\192-.jpeg',
#  'covid\\194.jpeg',
#  'covid\\1941783219e70684e715faaf7f70a834.jpg',
#  'covid\\195.jpeg',
#  'covid\\196-.jpeg',
#  'covid\\198.jpg',
#  'covid\\19abe1f3.png',
#  'covid\\19b9f2708595e4732d2a70f869c784b1.jpg',
#  'covid\\201.jpg',
#  'covid\\202.jpg',
#  'covid\\203.jpeg',
#  'covid\\204.jpg',
#  'covid\\206.jpg',
#  'covid\\215e4b0611070157c13926cda87f4fd5.jpg',
#  'covid\\2168a917.png',
#  'covid\\219ec6661ac0d29056a79bc961d6d321.jpg',
#  'covid\\220-.jpeg',
#  'covid\\221.jpeg',
#  'covid\\222.jpeg',
#  'covid\\223.jpg',
#  'covid\\224.jpg',
#  'covid\\225.jpg',
#  'covid\\226.jpg',
#  'covid\\230ff26069bdd17aa160628c302691b5.jpg',
#  'covid\\231.jpg',
#  'covid\\23E99E2E-447C-46E5-8EB2-D35D12473C39-1068x801.png',
#  'covid\\23E99E2E-447C-46E5-8EB2-D35D12473C39.png',
#  'covid\\243.jpeg',
#  'covid\\245.jpeg',
#  'covid\\247.jpeg',
#  'covid\\249.jpeg',
#  'covid\\24a843b649705927eaf22d33a06f3fe5.jpg',
#  'covid\\24c60f17531a1ff5c69582e0e83bab3b.jpg',
#  'covid\\253.jpeg',
#  'covid\\259.jpeg',
#  'covid\\25a7daabddcec8d1d426f584dd288da5.jpg',
#  'covid\\260.jpg',
#  'covid\\261.jpg',
#  'covid\\262.jpg',
#  'covid\\263.jpg',
#  'covid\\265.jpg',
#  'covid\\266.jpg',
#  'covid\\267.jpg',
#  'covid\\268.jpg',
#  'covid\\269.jpg',
#  'covid\\26c836ae7a2ed6c10b41017b62624c87.jpg',
#  'covid\\271.jpg',
#  'covid\\2712b7e4d23d1ae18b9cc2c65ba5ae54.jpg',
#  'covid\\272.jpg',
#  'covid\\276.jpg',
#  'covid\\279.jpg',
#  'covid\\27c962cd40f5c01cc81823d70f05a877.jpg',
#  'covid\\280-.jpg',
#  'covid\\280355c7aadb6d3ee144b8fbebf3edd8.jpg',
#  'covid\\281.jpg',
#  'covid\\282-.jpg',
#  'covid\\283.jpg',
#  'covid\\286.jpg',
#  'covid\\287.jpg',
#  'covid\\28b3cd86618b2140c587446f9d630bfd.jpg',
#  'covid\\295.jpg',
#  'covid\\296-.jpg',
#  'covid\\2966893D-5DDF-4B68-9E2B-4979D5956C8E.jpeg',
#  'covid\\297.jpg',
#  'covid\\298.jpg',
#  'covid\\29de8b02cf0cef948a1223228a3cfcb0.jpg',
#  'covid\\29fc5ddbf916319a529915c67ca4cda6.jpg',
#  'covid\\2a64e165ffeaa49d4ab0d41afa375dec.jpg',
#  'covid\\2abdd93f367360ea1b130c49ac504083.jpg',
#  'covid\\2acd5312277042f396e3f972cb20ff7e.jpg',
#  'covid\\2afa444de6b6139541731445ab57c838.jpg',
#  'covid\\2b3a04ae4c95bc84b8e748573626a4a0.jpg',
#  'covid\\2B8649B2-00C4-4233-85D5-1CE240CF233B.jpeg',
#  'covid\\2b8a6c4ef48ab221d057f20410f3f97b.jpg',
#  'covid\\2C10A413-AABE-4807-8CCE-6A2025594067.jpeg',
#  'covid\\2C26F453-AF3B-4517-BB9E-802CF2179543-1068x818.jpeg',
#  'covid\\2C26F453-AF3B-4517-BB9E-802CF2179543.jpeg',
#  'covid\\2c35005f.png',
#  'covid\\2cc9ddf172d282534c59eda12e44469a.jpg',
#  'covid\\2cd63b76.png',
#  'covid\\2ddaa4e218bda4446220b48d0ada3547.jpg',
#  'covid\\2ef227ba17c60e5ae53b3ece6d875096.jpg',
#  'covid\\2f666df1358be1567d1f26a214d09fad.jpg',
#  'covid\\2fd86eaa4fabfdd573fe646563435ea1.jpg',
#  'covid\\303.jpg',
#  'covid\\303eae81561c48dd64a15e03f8b66ac7.jpg',
#  'covid\\303ef287e17607d0ed2fdf815bde029c.jpg',
#  'covid\\305edda2a786eb4c888354109a51697c.jpg',
#  'covid\\306.jpg',
#  'covid\\307.jpg',
#  'covid\\30bd979b93881a48f0731275420f1ed5.jpg',
#  'covid\\310.jpg',
#  'covid\\311.jpg',
#  'covid\\312.jpg',
#  'covid\\313.jpg',
#  'covid\\314.jpg',
#  'covid\\315.jpg',
#  'covid\\316.jpg',
#  'covid\\317.jpg',
#  'covid\\31BA3780-2323-493F-8AED-62081B9C383B.jpeg',
#  'covid\\32516a638ec1793052ebb9ee55872c86.jpg',
#  'covid\\32fb49508672e3010c43be25eff8a9dc.jpg',
#  'covid\\336086ae9d4791685bbe4ad951650ad1.jpg',
#  'covid\\33c140260e50a183835b7c7c26c3c04c.jpg',
#  'covid\\34efdc647ec140749e16ba6b5f8ee10d.jpg',
#  'covid\\353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB-768x632.jpeg',
#  'covid\\353889E0-A1E8-4F9E-A0B8-F24F36BCFBFB.jpeg',
#  'covid\\359153d10985b1cec81485b19979183c.jpg',
#  'covid\\36e549a1f86e2bb6ee4385fd3800bb29.jpg',
#  'covid\\3789c6bcfd0934d0ddf4c79be444a167.jpg',
#  'covid\\3795f2894037a5f089c483d194f60126.jpg',
#  'covid\\384070301b9f203b17e928e3c7efa27c.jpg',
#  'covid\\39482b07eddc3e0ec4bccddf5006d5d4.jpg',
#  'covid\\39b131a142c9384da69eb801b4df9be6.jpg',
#  'covid\\39EE8E69-5801-48DE-B6E3-BE7D1BCF3092-1068x892.jpeg',
#  'covid\\39EE8E69-5801-48DE-B6E3-BE7D1BCF3092.jpeg',
#  'covid\\3a199bbfc92777323a92a64c088a5354.jpg',
#  'covid\\3a1c7e55986c2b2032a447ca0ae3f9cf.jpg',
#  'covid\\3a322b52516532277d0e883b6dd04e60.jpg',
#  'covid\\3a81faf3.png',
#  'covid\\3b46de94.png',
#  'covid\\3bc257ca4989b0d591869f31efc2dc9e.jpg',
#  'covid\\3c8d16fb9644e65b7f2236c6c2fec615.jpg',
#  'covid\\3d616e94a25732cbe8dbd7adb26e0d12.jpg',
#  'covid\\3dce450627222a06b985d7386c68a6ee.jpg',
#  'covid\\3e75c4140f78570872e8232516d0d57c.jpg',
#  'covid\\3f22a15eb58e4518bf3ec346ef34c793.jpg',
#  'covid\\3f26d16f398a0c305a77459a24ebc857.jpg',
#  'covid\\40359374a4d9533b8142dabb2dc1d9c5.jpg',
#  'covid\\4067eeff4d68fa4020d5dff081f85b0d.jpg',
#  'covid\\4078f3bf0e97e45f2490d29f71a8f6fe.jpg',
#  'covid\\40f5ef900d2bc4f18483c25761aecfc9.jpg',
#  'covid\\4114104143d08f3443017e9ab2396512.jpg',
#  'covid\\41591_2020_819_Fig1_HTML.webp-day10.png',
#  'covid\\41591_2020_819_Fig1_HTML.webp-day5.png',
#  'covid\\4196f5092c66e1739440f61b18897571.jpg',
#  'covid\\42ca96eef4071b3ee8e8349c4734670e.jpg',
#  'covid\\43eaa87a8c72d4928421f183ebfcfe81.jpg',
#  'covid\\4414e42e0c548ee395efcc4d5f56f6c5.jpg',
#  'covid\\4495ccc6aaa894a980c10598b7fa4260.jpg',
#  'covid\\451442bde50be59707a175fbc0f0ac96.jpg',
#  'covid\\45b949b941a061bb6ce258f0fc77ad73.jpg',
#  'covid\\4640009613ae51a1ddd7f4d3947d2291.jpg',
#  'covid\\474.jpg',
#  'covid\\475bdbc5d86e6a2de022f818af35837a.jpg',
#  'covid\\477.jpg',
#  'covid\\478.jpg',
#  'covid\\479.jpg',
#  'covid\\480.jpg',
#  'covid\\481p-.jpg',
#  'covid\\482p-.jpg',
#  'covid\\483.png',
#  'covid\\484p.png',
#  'covid\\485-.png',
#  'covid\\486p.png',
#  'covid\\487.png',
#  'covid\\48B3A812-F0CE-4B35-8A2C-88E5550E81EF-1068x885.jpeg',
#  'covid\\48e797d558a8d30522f8e19d54759748.jpg',
#  'covid\\490-.png',
#  'covid\\491-.png',
#  'covid\\492.png',
#  'covid\\493.jpg',
#  'covid\\494.jpg',
#  'covid\\497.jpg',
#  'covid\\498.jpg',
#  'covid\\499.jpg',
#  'covid\\4a7c65ba713f5e179ffcf0409998cb2a.jpg',
#  'covid\\4aa0686b1044f31f2bd1b4309920e2ca.jpg',
#  'covid\\4aa0e5648c56944cc91030b5ae9d07eb.jpg',
#  'covid\\4aa97eac9650c59c5f7ddd1ed11e7ccc.jpg',
#  'covid\\4ad30bc6-2da0-4f84-bc9b-62acabfd518a.annot.original.png',
#  'covid\\4af763d775574e08540714f5b66a0c43.jpg',
#  'covid\\4c7e2b93a6d2ede58d44df5065d08a92.jpg',
#  'covid\\4c920f1e650368e4c1cb06710e340c64.jpg',
#  'covid\\4d98e1de.png',
#  'covid\\4e43e48d52c9e2d4c6c1fb9bc1544f_jumbo.jpeg',
#  'covid\\4ebcd84b929d013792fc11f228d25790.jpg',
#  'covid\\4eece663b53e527c68b5309cc722f786.jpg',
#  'covid\\4f5811f07cc4546681cc9d7ff34f03e5.jpg',
#  'covid\\4f7aad412406ee9d1ca3803210fb92cb.jpg',
#  'covid\\4fc5e16730890b823d278c1d35c61c8e.jpg',
#  'covid\\500.jpg',
#  'covid\\501.jpg',
#  'covid\\503.jpg',
#  'covid\\504-.jpg',
#  'covid\\505.jpg',
#  'covid\\509.jpeg',
#  'covid\\50af0655a34ddad9915800e591d16114.jpg',
#  'covid\\50dd4a7e2828f1991ae5cbcb401e9bc2.jpg',
#  'covid\\512.png',
#  'covid\\515.png',
#  'covid\\516.png',
#  'covid\\518.png',
#  'covid\\521fa2df808a1add787892595608276b.jpg',
#  'covid\\522.png',
#  'covid\\524.png',
#  'covid\\526.png',
#  'covid\\527-.png',
#  'covid\\52779d88e9319e3afd9b0283966a96e2.jpg',
#  'covid\\530.png',
#  'covid\\531-.png',
#  'covid\\532-.png',
#  'covid\\535737b5db4d070104246eb07a89fd09.jpg',
#  'covid\\539-.png',
#  'covid\\53a0912bc24bc9e736ae07bb674a3f82.jpg',
#  'covid\\540db1f787ce5bcf86eef027ca7ab92a.jpg',
#  'covid\\541129c5f5f71dc15732f61ad2c30679.jpg',
#  'covid\\546.png',
#  'covid\\547.png',
#  'covid\\552.png',
#  'covid\\553.png',
#  'covid\\556.png',
#  'covid\\55d8e0dd862cdee117445a48fc2cf625.jpg',
#  'covid\\560.png',
#  'covid\\565-.png',
#  'covid\\572.png',
#  'covid\\5739b66f3e5a086cb1d5273bd880cc05.jpg',
#  'covid\\574.png',
#  'covid\\57770e681193e9a6fda4e11df422e42e.jpg',
#  'covid\\5782ae15.png',
#  'covid\\57ee973a3ca433c4ea0cb7c9b2cbc382.jpg',
#  'covid\\57f27146fd2ab157e581a12f4c3a068f.jpg',
#  'covid\\581.png',
#  'covid\\582.png',
#  'covid\\585.png',
#  'covid\\588.png',
#  'covid\\589.png',
#  'covid\\58cb9263f16e94305c730685358e4e_jumbo.jpeg',
#  'covid\\590-.png',
#  'covid\\592.png',
#  'covid\\5931B64A-7B97-485D-BE60-3F1EA76BC4F0.jpeg',
#  'covid\\595.png',
#  'covid\\598-.png',
#  'covid\\5a0a97ecf6859f16544c37459a790a04.jpg',
#  'covid\\5A78BCA9-5B7A-440D-8A4E-AE7710EA6EAD-1068x866.jpeg',
#  'covid\\5A78BCA9-5B7A-440D-8A4E-AE7710EA6EAD.jpeg',
#  'covid\\5b38e298ab740da1e6d6cba36bbb39a4.jpg',
#  'covid\\5c8a543ed1add30449ff0fab01cd2ed1.jpg',
#  'covid\\5ca2dabd78fac825d658ad91e5676c5d.jpg',
#  'covid\\5CBC2E94-D358-401E-8928-965CCD965C5C-768x633.jpeg',
#  'covid\\5CBC2E94-D358-401E-8928-965CCD965C5C.jpeg',
#  'covid\\5cec7954a301d42225cbad968048c597.jpg',
#  'covid\\5d4e502e165c3e833929947f3ad5269f.jpg',
#  'covid\\5df973284e61359a86c3d5bf3cd5b0dd.jpg',
#  'covid\\5e6dd879fde9502400e58b2f.jpeg',
#  'covid\\5ed09c63d407c576fc20b7c50fbc9066.jpg',
#  'covid\\5eeda2bc9bdcfc8005efcc6bde619291.jpg',
#  'covid\\5f2c0b45a4fcfd0fd4cf06b858f856d4.jpg',
#  'covid\\5f619d7e.png',
#  'covid\\5f7b385da84fb4be5d70b5dae9690692.jpg',
#  'covid\\5ff062df4b59dc8880ee6f6da4c730d2.jpg',
#  'covid\\606.png',
#  'covid\\607-.png',
#  'covid\\612.png',
#  'covid\\614.png',
#  'covid\\615.png',
#  'covid\\615d5243ae86bb7a21bed6591a2cbeb2.jpg',
#  'covid\\616.png',
#  'covid\\617.png',
#  'covid\\619.png',
#  'covid\\619d0a1d17d45b9b2113a0a41e0694f5.jpg',
#  'covid\\61e3d47e250e211f193065103f41d8cd.jpg',
#  'covid\\61ecfcaf796ebaf3dda37c5bca42434c.jpg',
#  'covid\\61f45c632bb29f7c5752c6e49ca55d37.jpg',
#  'covid\\621.png',
#  'covid\\623dc289cab336f88cb5b159315dcdae.jpg',
#  'covid\\624.png',
#  'covid\\628fb35cbf926cac49e84b2fd75bfb4b.jpg',
#  'covid\\630-.png',
#  'covid\\631.png',
#  'covid\\632.png',
#  'covid\\634.png',
#  'covid\\635.png',
#  'covid\\640.png',
#  'covid\\642.png',
#  'covid\\643.png',
#  'covid\\644.png',
#  'covid\\649.png',
#  'covid\\650353c8029700c27d95718534e43708.jpg',
#  'covid\\656.png',
#  'covid\\657.png',
#  'covid\\658.png',
#  'covid\\658baee0fc633021698054b9c83423c3.jpg',
#  'covid\\659.png',
#  'covid\\661.png',
#  'covid\\661b5807eac8deaf3adcb908d34ecf44.jpg',
#  'covid\\662.png',
#  'covid\\664.png',
#  'covid\\674.jpg',
#  'covid\\675.jpg',
#  'covid\\676.jpg',
#  'covid\\680.jpg',
#  'covid\\681.jpg',
#  'covid\\682.jpg',
#  'covid\\683.jpg',
#  'covid\\684.jpg',
#  'covid\\6b1a5a5c8028390cdeec67a375453b24.jpg',
#  'covid\\6b3bdbc31f65230b8cdcc3cef5f8ba8a-40ac-0.jpg',
#  'covid\\6b44464d-73a7-4cf3-bbb6-ffe7168300e3.annot.original.jpeg',
#  'covid\\6b661a599b0467a21d80f2df0d137a74.jpg',
#  'covid\\6b84633cf7dff4c51066fc93ffae3671.jpg',
#  'covid\\6b9f799d9d1c20ae386f7890a47d523d.jpg',
#  'covid\\6ba15e1949ee2ee3a27efd92c14215a6.jpg',
#  'covid\\6bd45d762a283c8b02f9740571e07c57.jpg',
#  'covid\\6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7-768x495.jpeg',
#  'covid\\6CB4EFC6-68FA-4CD5-940C-BEFA8DAFE9A7.jpeg',
#  'covid\\6cc4a8c617284d9dd42d63213ddbf83d.jpg',
#  'covid\\6d6ce8cee82b41158c1375d4af162559.jpg',
#  'covid\\6d8bc73a3ab40b738f101e0d69c680dc.jpg',
#  'covid\\6e0076fc8129831a147ecbb096d6be7d.jpg',
#  'covid\\6eaceb079761a9fd8e3382c08c626b3c.jpg',
#  'covid\\6ef1214d267b5dfe5d1c06da5dc96c18.jpg',
#  'covid\\6f00f459176caab0647d5aab03c304c2.jpg',
#  'covid\\6f0e97b2d27d79fa54bc2174653f7841.jpg',
#  'covid\\703242e304a86711f603617591b92113.jpg',
#  'covid\\706-.png',
#  'covid\\707-.jpg',
#  'covid\\708.jpg',
#  'covid\\709.jpg',
#  'covid\\710.png',
#  'covid\\711.jpeg',
#  'covid\\715.png',
#  'covid\\716.png',
#  'covid\\717.png',
#  'covid\\718218972a42cb033423dcd2c332a356.jpg',
#  'covid\\72240b3cdd0fe06a9d6f8793f3c880fb.jpg',
#  'covid\\730-.jpg',
#  'covid\\739.jpg',
#  'covid\\740.jpeg',
#  'covid\\742.png',
#  'covid\\743.png',
#  'covid\\74615ac65b6040f7fa1122e383d06ffc.jpg',
#  'covid\\746b5795defec9183ed22977bc6c77c0.jpg',
#  'covid\\748.png',
#  'covid\\749.png',
#  'covid\\750.png',
#  'covid\\751.png',
#  'covid\\751d46bc78c5b9f855ce311cd5004e7a.jpg',
#  'covid\\752.png',
#  'covid\\755.png',
#  'covid\\7632c0b5f546c67ff649281d14e5ee18.jpg',
#  'covid\\770585a15ab0b2a1ff2b1934346abe8f.jpg',
#  'covid\\771289b3cb9a1fbe66f609ba31441600.jpg',
#  'covid\\77947a62dc37fa59eb9fea8b80cc1195.jpg',
#  'covid\\780a90391a4e821e1f50b0ba01c369ba.jpg',
#  'covid\\7870c789e5ac8b57cb63918bf91f0ddb.jpg',
#  'covid\\787134f16e67a165c4a5a104a3b16248.jpg',
#  'covid\\7918a9dc35c79d905d095f2797c22926.jpg',
#  'covid\\793ae4e46b8b28f5d90f8e604dd25fcf.jpg',
#  'covid\\794333f81264733f02a4d0ee0f8b4797.jpg',
#  'covid\\7AF6C1AF-D249-4BD2-8C26-449304105D03-1068x881.jpeg',
#  'covid\\7AF6C1AF-D249-4BD2-8C26-449304105D03.jpeg',
#  'covid\\7afaaccc.png',
#  'covid\\7ba7e1ae478b6cd1eb7c54fc3454b5ac.jpg',
#  'covid\\7bacd6438d9c17d7d6c15ef5f77dce19.jpg',
#  'covid\\7c1e33e0cfcb5752e7669ac71139eed6.jpg',
#  'covid\\7c3e4eb5cb84b811154761c1a0ebd9bf.jpg',
#  'covid\\7C69C012-7479-493F-8722-ABC29C60A2DD-1068x1063.jpeg',
#  'covid\\7C69C012-7479-493F-8722-ABC29C60A2DD.jpeg',
#  'covid\\7D2CF6CE-F529-4470-8356-D33FFAF98600.jpeg',
#  'covid\\7db5eec6821db6d1aac411c0ad9c3faa.jpg',
#  'covid\\7e6133f4676facc1bd6c909c65037286.jpg',
#  'covid\\7ec445ed6034ed610a43877369354aa4.jpg',
#  'covid\\7EF28E12-F628-4BEC-A8C5-E6277C2E4F60.png',
#  'covid\\7f0c527cba96a7930bfa3d2b5850f944.jpg',
#  'covid\\80446565-E090-4187-A031-9D3CEAA586C8.jpeg',
#  'covid\\816c5a1c4c10ec89bc0a01f921016a27.jpg',
#  'covid\\830e53fdadc98dfaeba6eda788254408.jpg',
#  'covid\\83641c55b3c787dab50c271846ce11b6.jpg',
#  'covid\\83961a1b75fc80b9761608c3d98d50a2.jpg',
#  'covid\\840ba4c8e302da54e8a2c38330477e2e.jpg',
#  'covid\\846f661053c789c29dfcc73618dcf104.jpg',
#  'covid\\851cb94bc820fc4f75cab6302de4c5a6.jpg',
#  'covid\\867ff47484476b362360d20f0ba53eef.jpg',
#  'covid\\871e9cdecc71de9594cf5a94e49d6018.jpg',
#  'covid\\87342e39c5f1486114022acfd3631540.jpg',
#  'covid\\88774a3a819b6b8f5e230e94c652a042.jpg',
#  'covid\\88850d1994c4210f080007d2a6fb9094.jpg',
#  'covid\\88859dc1.png',
#  'covid\\8907d309d31e2facf4878b43e198aa8b.jpg',
#  'covid\\89451d8abee98a8e6c1bbb130e3f4787.jpg',
#  'covid\\8a0e8f382ac69d58c08f9e3663971da6.jpg',
#  'covid\\8a362b5dc9fff1f31630ac292739ad73.jpg',
#  'covid\\8da14fff.png',
#  'covid\\8e3eb8b71030de2642495effe002f0b6.jpg',
#  'covid\\8ea23d2666bdfe2da5246f0cfffccfb2.jpg',
#  'covid\\8fc103ca.png',
#  'covid\\8FDE8DBA-CFBD-4B4C-B1A4-6F36A93B7E87.jpeg',
#  'covid\\90316662d729b805001e47fe43f03ea5.jpg',
#  'covid\\90986ce4.png',
#  'covid\\909a4e596ceb3de60a4314df4bf58da2.jpg',
#  'covid\\91426f3297dc431f2b9fbd4bb56ab4f0.jpg',
#  'covid\\925ae41898868450151861d42351d280.jpg',
#  'covid\\949b78097ccc32f5681d2e52a1089353.jpg',
#  'covid\\951943c31df68727d9a59faf79cda897.jpg',
#  'covid\\9530a643fdc6b00a4d55ee96d134b808.jpg',
#  'covid\\9626cd192197464393263cfebee5e144.jpg',
#  'covid\\9707879a3e75d4d62f177813667f5980.jpg',
#  'covid\\9a000982924e3a1777e7591dfb25969c.jpg',
#  'covid\\9a6f0861b6c11ce7c7861706990f3ff2.jpg',
#  'covid\\9aa88ab1a9df8ed5ba130083a3d1528c.jpg',
#  'covid\\9b2ce7c8e28bf8b607c9268e4c764c72.jpg',
#  'covid\\9C34AF49-E589-44D5-92D3-168B3B04E4A6.jpeg',
#  'covid\\9c62e843fb2ca9ec9e29fb96411e8480.jpg',
#  'covid\\9c853c25a1c53cfd2b31ad20df749265.jpg',
#  'covid\\9cabd1317d5ab07732d82c3e073e5c62.jpg',
#  'covid\\9d7e4aaa8039e77bdfebd30b746188d2.jpg',
#  'covid\\9dab1fc8d9573b336590123a3e1de832.jpg',
#  'covid\\9db9692c5c119fd9ddfce51d1988c3c2.jpg',
#  'covid\\9dc336affe379f5106f523f56a259a1e.jpg',
#  'covid\\9f830169a0b33625f91420d921b8d71b.jpg',
#  'covid\\9fdd3c3032296fd04d2cad5d9070d4_jumbo.jpeg',
#  'covid\\a0b85f95aa4762b9cb886224a7433fa8.jpg',
#  'covid\\a207ea332bfc2450fd11b07fd0095180.jpg',
#  'covid\\a20e84e08ae6a2c915bbe665e35a4db8.jpg',
#  'covid\\a2c2afa695096bbe041aa7970bb52ddf.jpg',
#  'covid\\a2eba651.png',
#  'covid\\a361d7b7.png',
#  'covid\\a37bd490ba8fd3f5ff6bbb91f2dd34a9.jpg',
#  'covid\\a3c50196fd57cc67041fd1b7c13cdc14.jpg',
#  'covid\\a4486bf2e897d105ed4f0c5c5163e575.jpg',
#  'covid\\a45df0a70c760802abb5998e2dfc7a5a.jpg',
#  'covid\\a6d5c095f58900d1da3fc50cddb7e9e5.jpg',
#  'covid\\a7e26028487da7ca6a4344948ebb7365.jpg',
#  'covid\\A7E260CE-8A00-4C5F-A7F5-27336527A981-1068x1092.jpeg',
#  'covid\\A7E260CE-8A00-4C5F-A7F5-27336527A981.jpeg',
#  'covid\\a80b6cf809ac8356122890b2bbb8cce1.jpg',
#  'covid\\a85dee301d6090dd534caeca37e8ca22.jpg',
#  'covid\\a8794f655f62b99fda33f59186ad02e4.jpg',
#  'covid\\a8ac1969.png',
#  'covid\\a900ad4d645ec5b706b6c5477af19eb4.jpg',
#  'covid\\a95d20a8a40ca7e388fa3fbcec4b0410.jpg',
#  'covid\\a9d1b5e636b5d5334be04aade4d28cd1.jpg',
#  'covid\\aadad5f1a07bff9f472089e58510b418.jpg',
#  'covid\\aaecbc9358332d61c86813dad33ed55a.jpg',
#  'covid\\abc2b50068e084fed29599e3c87bef11.jpg',
#  'covid\\abcc9dbbf376786fdea3351ac09190f4.jpg',
#  'covid\\ac4f6e4e.png',
#  'covid\\acc0d9ce7f5f5ce7356911cfc95ea744.jpg',
#  'covid\\ada8c494.png',
#  'covid\\aeea95cb8a7aa09fcd9df9e67e49051e.jpg',
#  'covid\\af47db6c1b39cdb22e1a1561640bd85b.jpg',
#  'covid\\auntminnie-2020_01_31_20_24_2322_2020_01_31_x-ray_coronavirus_US.jpg',
#  'covid\\auntminnie-a-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'covid\\auntminnie-b-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'covid\\auntminnie-c-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'covid\\auntminnie-d-2020_01_28_23_51_6665_2020_01_28_Vietnam_coronavirus.jpeg',
#  'covid\\b0d8f12cb190292be0a9597dd72604c9.jpg',
#  'covid\\b1b3cd8a6c85f841d30b4dc686eb90a2.jpg',
#  'covid\\b2e4cf32805450bee8565637365a4783.jpg',
#  'covid\\b51f7ed95e9b0f0ce0531b9a45bdf778.jpg',
#  'covid\\b54c867526ae17f499d67cf51f1d1560.jpg',
#  'covid\\B59DD164-51D5-40DF-A926-6A42DD52EBE8.jpeg',
#  'covid\\b6f26b3314e6e5b3b0730d3b403c9342.jpg',
#  'covid\\b7a40dd8c25fab8c9b15f294692156a3.jpg',
#  'covid\\b7b81cccc1bf1564cf465bdd8f6ab18b.jpg',
#  'covid\\b7d1d4d3b0e0510d3d22baf412a60b89.jpg',
#  'covid\\b7ec474861dd86b6c41bc45e435494a8.jpg',
#  'covid\\b8c9af95c30018efccd5572bf035f258.jpg',
#  'covid\\b8eb975390a6f21df352d37ff122b55e.jpg',
#  'covid\\b9ca4b5935d9b4f4448de67c7409a937.jpg',
#  'covid\\c12f6fb11573e5db832d74ae688b0568.jpg',
#  'covid\\c138b20525e3e7773a25237b6275e81a.jpg',
#  'covid\\c206deb234d5e5c77da8832e96698a58.jpg',
#  'covid\\c34c933f98c9e142b4e88215bae5010f.jpg',
#  'covid\\c3616f0b0919805c972aac6b95910844.jpg',
#  'covid\\c3829ecb.png',
#  'covid\\c39d53e15f7e9c4fb2c79b5c2e5000dd.jpg',
#  'covid\\c4afba8657601827dd2e6f755a8d6829.jpg',
#  'covid\\c4bfbcea6d83b7694be30e7f32a6f26b.jpg',
#  'covid\\c601f50d.png',
#  'covid\\c6ab65ab570fdab83015247eb538c146.jpg',
#  'covid\\c6d8608ddd4737798a6c7595523ec9dd.jpg',
#  'covid\\c787fb5d1ed7f425fea970f25ae8c71f.jpg',
#  'covid\\c7ede8f74fc8cc5191d1943d19292a96.jpg',
#  'covid\\c9f4beda36388a49caa5222168cec0ca.jpg',
#  'covid\\case_71_figura1.png',
#  'covid\\case_72_RX-TORACE1.jpg',
#  'covid\\cbc6a73b61495db72cd74c3d990419c8.jpg',
#  'covid\\cd1a1e20b5004e8304915dcde776bb99.jpg',
#  'covid\\cd40a9768ebc7fab3030fc25c40df76e.jpg',
#  'covid\\CD50BA96-6982-4C80-AE7B-5F67ACDBFA56-1068x875.jpeg',
#  'covid\\CD50BA96-6982-4C80-AE7B-5F67ACDBFA56.jpeg',
#  'covid\\ce2efe8068fbce6e522ddca8f1423ce4.jpg',
#  'covid\\cf5199b4f9c5f6bf7a19e5abd06db0d5.jpg',
#  'covid\\ciaa199.pdf-001-b.png',
#  'covid\\ciaa199.pdf-001-c.png',
#  'covid\\COVID-00010.jpg',
#  'covid\\COVID-00011.jpg',
#  'covid\\COVID-00012.jpg',
#  'covid\\COVID-00013a.jpg',
#  'covid\\COVID-00013b.jpg',
#  'covid\\COVID-00014.jpg',
#  'covid\\COVID-00015a.png',
#  'covid\\COVID-00015b.png',
#  'covid\\COVID-00016.jpg',
#  'covid\\COVID-00017.jpg',
#  'covid\\COVID-00018.jpg',
#  'covid\\COVID-00019.jpg',
#  'covid\\COVID-00020.jpg',
#  'covid\\COVID-00021.jpg',
#  'covid\\COVID-00022.jpg',
#  'covid\\COVID-00023.jpg',
#  'covid\\COVID-19 (1).jpeg',
#  'covid\\COVID-19 (1).jpg',
#  'covid\\COVID-19 (1).png',
#  'covid\\COVID-19 (10).jpeg',
#  'covid\\COVID-19 (10).jpg',
#  'covid\\COVID-19 (11).jpeg',
#  'covid\\COVID-19 (11).jpg',
#  'covid\\COVID-19 (12).jpg',
#  'covid\\COVID-19 (13).jpeg',
#  'covid\\COVID-19 (13).jpg',
#  'covid\\COVID-19 (14).jpg',
#  'covid\\COVID-19 (15).jpeg',
#  'covid\\COVID-19 (15).jpg',
#  'covid\\COVID-19 (156).jpg',
#  'covid\\COVID-19 (157).jpg',
#  'covid\\COVID-19 (158).jpg',
#  'covid\\COVID-19 (159).jpg',
#  'covid\\COVID-19 (16).jpeg',
#  'covid\\COVID-19 (16).jpg',
#  'covid\\COVID-19 (160).jpg',
#  'covid\\COVID-19 (161).jpg',
#  'covid\\COVID-19 (162).jpg',
#  'covid\\COVID-19 (163).jpg',
#  'covid\\COVID-19 (164).jpg',
#  'covid\\COVID-19 (165).jpg',
#  'covid\\COVID-19 (166).jpg',
#  'covid\\COVID-19 (167).jpg',
#  'covid\\COVID-19 (168).jpg',
#  'covid\\COVID-19 (169).jpg',
#  'covid\\COVID-19 (17).jpeg',
#  'covid\\COVID-19 (17).jpg',
#  'covid\\COVID-19 (170).jpg',
#  'covid\\COVID-19 (171).jpg',
#  'covid\\COVID-19 (172).jpg',
#  'covid\\COVID-19 (173).jpg',
#  'covid\\COVID-19 (174).jpg',
#  'covid\\COVID-19 (175).jpg',
#  'covid\\COVID-19 (176).jpg',
#  'covid\\COVID-19 (177).jpg',
#  'covid\\COVID-19 (178).jpg',
#  'covid\\COVID-19 (179).jpg',
#  'covid\\COVID-19 (18).jpeg',
#  'covid\\COVID-19 (18).jpg',
#  'covid\\COVID-19 (180).jpg',
#  'covid\\COVID-19 (181).jpg',
#  'covid\\COVID-19 (182).jpg',
#  'covid\\COVID-19 (183).jpg',
#  'covid\\COVID-19 (184).jpg',
#  'covid\\COVID-19 (185).jpg',
#  'covid\\COVID-19 (188).jpg',
#  'covid\\COVID-19 (189).jpg',
#  'covid\\COVID-19 (19).jpeg',
#  'covid\\COVID-19 (19).jpg',
#  'covid\\COVID-19 (193).jpg',
#  'covid\\COVID-19 (194).jpg',
#  'covid\\COVID-19 (195).jpg',
#  'covid\\COVID-19 (196).jpg',
#  'covid\\COVID-19 (197).jpg',
#  'covid\\COVID-19 (198).jpg',
#  'covid\\COVID-19 (199).jpg',
#  'covid\\COVID-19 (2).jpeg',
#  'covid\\COVID-19 (2).png',
#  'covid\\COVID-19 (20).jpeg',
#  'covid\\COVID-19 (20).jpg',
#  'covid\\COVID-19 (200).jpg',
#  'covid\\COVID-19 (201).jpg',
#  'covid\\COVID-19 (202).jpg',
#  'covid\\COVID-19 (203).jpg',
#  'covid\\COVID-19 (204).jpg',
#  'covid\\COVID-19 (205).jpg',
#  'covid\\COVID-19 (206).jpg',
#  'covid\\COVID-19 (207).jpg',
#  'covid\\COVID-19 (208).jpg',
#  'covid\\COVID-19 (209).jpg',
#  'covid\\COVID-19 (21).jpeg',
#  'covid\\COVID-19 (21).jpg',
#  'covid\\COVID-19 (210).jpg',
#  'covid\\COVID-19 (211).jpg',
#  'covid\\COVID-19 (212).jpg',
#  'covid\\COVID-19 (213).jpg',
#  'covid\\COVID-19 (214).jpg',
#  'covid\\COVID-19 (215).jpg',
#  'covid\\COVID-19 (216).jpg',
#  'covid\\COVID-19 (217).jpg',
#  'covid\\COVID-19 (218).jpg',
#  'covid\\COVID-19 (219).jpg',
#  'covid\\COVID-19 (22).jpeg',
#  'covid\\COVID-19 (22).jpg',
#  'covid\\COVID-19 (220).jpg',
#  'covid\\COVID-19 (221).jpg',
#  'covid\\COVID-19 (222).jpg',
#  'covid\\COVID-19 (223).jpg',
#  'covid\\COVID-19 (224).jpg',
#  'covid\\COVID-19 (225).jpg',
#  'covid\\COVID-19 (226).jpg',
#  'covid\\COVID-19 (227).jpg',
#  'covid\\COVID-19 (228).jpg',
#  'covid\\COVID-19 (229).jpg',
#  'covid\\COVID-19 (23).jpeg',
#  'covid\\COVID-19 (23).jpg',
#  'covid\\COVID-19 (230).jpg',
#  'covid\\COVID-19 (231).jpg',
#  'covid\\COVID-19 (232).jpg',
#  'covid\\COVID-19 (233).jpg',
#  'covid\\COVID-19 (234).jpg',
#  'covid\\COVID-19 (235).jpg',
#  'covid\\COVID-19 (236).jpg',
#  'covid\\COVID-19 (237).jpg',
#  'covid\\COVID-19 (238).jpg',
#  'covid\\COVID-19 (239).jpg',
#  'covid\\COVID-19 (240).jpg',
#  'covid\\COVID-19 (241).jpg',
#  'covid\\COVID-19 (242).jpg',
#  'covid\\COVID-19 (243).jpg',
#  'covid\\COVID-19 (244).jpg',
#  'covid\\COVID-19 (245).jpg',
#  'covid\\COVID-19 (246).jpg',
#  'covid\\COVID-19 (247).jpg',
#  'covid\\COVID-19 (248).jpg',
#  'covid\\COVID-19 (249).jpg',
#  'covid\\COVID-19 (25).jpeg',
#  'covid\\COVID-19 (250).jpg',
#  'covid\\COVID-19 (251).jpg',
#  'covid\\COVID-19 (252).jpg',
#  'covid\\COVID-19 (253).jpg',
#  'covid\\COVID-19 (254).jpg',
#  'covid\\COVID-19 (255).jpg',
#  'covid\\COVID-19 (256).jpg',
#  'covid\\COVID-19 (257).jpg',
#  'covid\\COVID-19 (258).jpg',
#  'covid\\COVID-19 (259).jpg',
#  'covid\\COVID-19 (26).jpeg',
#  'covid\\COVID-19 (260).jpg',
#  'covid\\COVID-19 (261).jpg',
#  'covid\\COVID-19 (262).jpg',
#  'covid\\COVID-19 (263).jpg',
#  'covid\\COVID-19 (264).jpg',
#  'covid\\COVID-19 (265).jpg',
#  'covid\\COVID-19 (266).jpg',
#  'covid\\COVID-19 (267).jpg',
#  'covid\\COVID-19 (268).jpg',
#  'covid\\COVID-19 (269).jpg',
#  'covid\\COVID-19 (270).jpg',
#  'covid\\COVID-19 (271).jpg',
#  'covid\\COVID-19 (272).jpg',
#  'covid\\COVID-19 (273).jpg',
#  'covid\\COVID-19 (274).jpg',
#  'covid\\COVID-19 (275).jpg',
#  'covid\\COVID-19 (29).jpeg',
#  'covid\\COVID-19 (294).jpg',
#  'covid\\COVID-19 (295).jpg',
#  'covid\\COVID-19 (296).jpg',
#  'covid\\COVID-19 (297).jpg',
#  'covid\\COVID-19 (298).jpg',
#  'covid\\COVID-19 (299).jpg',
#  'covid\\COVID-19 (3).jpeg',
#  'covid\\COVID-19 (3).jpg',
#  'covid\\COVID-19 (300).jpg',
#  'covid\\COVID-19 (301).jpg',
#  'covid\\COVID-19 (302).jpg',
#  'covid\\COVID-19 (303).jpg',
#  'covid\\COVID-19 (304).jpg',
#  'covid\\COVID-19 (305).jpg',
#  'covid\\COVID-19 (306).jpg',
#  'covid\\COVID-19 (307).jpg',
#  'covid\\COVID-19 (308).jpg',
#  'covid\\COVID-19 (309).jpg',
#  'covid\\COVID-19 (31).jpeg',
#  'covid\\COVID-19 (310).jpg',
#  'covid\\COVID-19 (311).jpg',
#  'covid\\COVID-19 (312).jpg',
#  'covid\\COVID-19 (313).jpg',
#  'covid\\COVID-19 (314).jpg',
#  'covid\\COVID-19 (315).jpg',
#  'covid\\COVID-19 (316).jpg',
#  'covid\\COVID-19 (317).jpg',
#  'covid\\COVID-19 (318).jpg',
#  'covid\\COVID-19 (319).jpg',
#  'covid\\COVID-19 (32).jpeg',
#  'covid\\COVID-19 (320).jpg',
#  'covid\\COVID-19 (321).jpg',
#  'covid\\COVID-19 (322).jpg',
#  'covid\\COVID-19 (323).jpg',
#  'covid\\COVID-19 (324).jpg',
#  'covid\\COVID-19 (325).jpg',
#  'covid\\COVID-19 (327).jpg',
#  'covid\\COVID-19 (328).jpg',
#  'covid\\COVID-19 (329).jpg',
#  'covid\\COVID-19 (330).jpg',
#  'covid\\COVID-19 (331).jpg',
#  'covid\\COVID-19 (332).jpg',
#  'covid\\COVID-19 (333).jpg',
#  'covid\\COVID-19 (334).jpg',
#  'covid\\COVID-19 (335).jpg',
#  'covid\\COVID-19 (336).jpg',
#  'covid\\COVID-19 (337).jpg',
#  'covid\\COVID-19 (338).jpg',
#  'covid\\COVID-19 (339).jpg',
#  'covid\\COVID-19 (340).jpg',
#  'covid\\COVID-19 (341).jpg',
#  'covid\\COVID-19 (342).jpg',
#  'covid\\COVID-19 (343).jpg',
#  'covid\\COVID-19 (344).jpg',
#  'covid\\COVID-19 (345).jpg',
#  'covid\\COVID-19 (346).jpg',
#  'covid\\COVID-19 (347).jpg',
#  'covid\\COVID-19 (348).jpg',
#  'covid\\COVID-19 (349).jpg',
#  'covid\\COVID-19 (350).jpg',
#  'covid\\COVID-19 (351).jpg',
#  'covid\\COVID-19 (352).jpg',
#  'covid\\COVID-19 (353).jpg',
#  'covid\\COVID-19 (354).jpg',
#  'covid\\COVID-19 (355).jpg',
#  'covid\\COVID-19 (356).jpg',
#  'covid\\COVID-19 (357).jpg',
#  'covid\\COVID-19 (358).jpg',
#  'covid\\COVID-19 (359).jpg',
#  'covid\\COVID-19 (360).jpg',
#  'covid\\COVID-19 (361).jpg',
#  'covid\\COVID-19 (362).jpg',
#  'covid\\COVID-19 (363).jpg',
#  'covid\\COVID-19 (364).jpg',
#  'covid\\COVID-19 (365).jpg',
#  'covid\\COVID-19 (371).jpg',
#  'covid\\COVID-19 (372).jpg',
#  'covid\\COVID-19 (373).jpg',
#  'covid\\COVID-19 (374).jpg',
#  'covid\\COVID-19 (375).jpg',
#  'covid\\COVID-19 (376).jpg',
#  'covid\\COVID-19 (377).jpg',
#  'covid\\COVID-19 (378).jpg',
#  'covid\\COVID-19 (379).jpg',
#  'covid\\COVID-19 (380).jpg',
#  'covid\\COVID-19 (381).jpg',
#  'covid\\COVID-19 (382).jpg',
#  'covid\\COVID-19 (383).jpg',
#  'covid\\COVID-19 (384).jpg',
#  'covid\\COVID-19 (385).jpg',
#  'covid\\COVID-19 (386).jpg',
#  'covid\\COVID-19 (387).jpg',
#  'covid\\COVID-19 (388).jpg',
#  'covid\\COVID-19 (389).jpg',
#  'covid\\COVID-19 (390).jpg',
#  'covid\\COVID-19 (391).jpg',
#  'covid\\COVID-19 (392).jpg',
#  'covid\\COVID-19 (393).jpg',
#  'covid\\COVID-19 (394).jpg',
#  'covid\\COVID-19 (395).jpg',
#  'covid\\COVID-19 (396).jpg',
#  'covid\\COVID-19 (397).jpg',
#  'covid\\COVID-19 (398).jpg',
#  'covid\\COVID-19 (399).jpg',
#  'covid\\COVID-19 (4).jpeg',
#  'covid\\COVID-19 (4).jpg',
#  'covid\\COVID-19 (400).jpg',
#  'covid\\COVID-19 (401).jpg',
#  'covid\\COVID-19 (402).jpg',
#  'covid\\COVID-19 (403).jpg',
#  'covid\\COVID-19 (404).jpg',
#  'covid\\COVID-19 (405).jpg',
#  'covid\\COVID-19 (406).jpg',
#  'covid\\COVID-19 (407).jpg',
#  'covid\\COVID-19 (408).jpg',
#  'covid\\COVID-19 (409).jpg',
#  'covid\\COVID-19 (410).jpg',
#  'covid\\COVID-19 (411).jpg',
#  'covid\\COVID-19 (412).jpg',
#  'covid\\COVID-19 (413).jpg',
#  'covid\\COVID-19 (414).jpg',
#  'covid\\COVID-19 (415).jpg',
#  'covid\\COVID-19 (42).jpg',
#  'covid\\COVID-19 (43).jpg',
#  'covid\\COVID-19 (437).jpg',
#  'covid\\COVID-19 (438).jpg',
#  'covid\\COVID-19 (439).jpg',
#  'covid\\COVID-19 (44).jpg',
#  'covid\\COVID-19 (440).jpg',
#  'covid\\COVID-19 (441).jpg',
#  'covid\\COVID-19 (442).jpg',
#  'covid\\COVID-19 (443).jpg',
#  'covid\\COVID-19 (444).jpg',
#  'covid\\COVID-19 (445).jpg',
#  'covid\\COVID-19 (446).jpg',
#  'covid\\COVID-19 (447).jpg',
#  'covid\\COVID-19 (448).jpg',
#  'covid\\COVID-19 (449).jpg',
#  'covid\\COVID-19 (45).jpg',
#  'covid\\COVID-19 (450).jpg',
#  'covid\\COVID-19 (451).jpg',
#  'covid\\COVID-19 (452).jpg',
#  'covid\\COVID-19 (453).jpg',
#  'covid\\COVID-19 (454).jpg',
#  'covid\\COVID-19 (455).jpg',
#  'covid\\COVID-19 (46).jpg',
#  'covid\\COVID-19 (47).jpg',
#  'covid\\COVID-19 (474).jpg',
#  'covid\\COVID-19 (475).jpg',
#  'covid\\COVID-19 (476).jpg',
#  'covid\\COVID-19 (477).jpg',
#  'covid\\COVID-19 (478).jpg',
#  'covid\\COVID-19 (479).jpg',
#  'covid\\COVID-19 (48).jpg',
#  'covid\\COVID-19 (480).jpg',
#  'covid\\COVID-19 (481).jpg',
#  'covid\\COVID-19 (482).jpg',
#  'covid\\COVID-19 (483).jpg',
#  'covid\\COVID-19 (484).jpg',
#  'covid\\COVID-19 (485).jpg',
#  'covid\\COVID-19 (486).jpg',
#  'covid\\COVID-19 (487).jpg',
#  'covid\\COVID-19 (488).jpg',
#  ...]

# %%
print(len(normals_list), len(covids_list))
# Out:
# 3022 2084

# %% [markdown]
# # 이미지파일을 RGB 3차원 배열로 불러오기

# %%
import cv2

# %%
#데이터 directory의 file path와 연결을 시켜주고, opencv에서 이미지형태로 불러올수 있도록 파일의 경로를 불러온다.
#BGR형태를 RGB형태로 바꿔준다.
def get_RGB_image(data_dir,file_name):
    image_file = os.path.join(data_dir, file_name)
    image = cv2.imread(image_file)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    
    return image

# %% [markdown]
# # 이미지데이터 확인하기
#
# - 정상과 코로나 이미지를 하나의 쌍으로 보기위해서 데이터셋 길이를 조절한다.

# %% [markdown]
# 1. 다양한 위젯: ipywidgets는 다양한 종류의 위젯을 제공한다. 이러한 위젯에는 텍스트 상자, 버튼, 드롭다운 목록, 슬라이더, 체크박스, 라디오 버튼 등이 포함된다.
#
#
# "위젯"은 "웹 위젯"의 줄임말로, 웹 기반 사용자 인터페이스 (UI) 요소를 가리킨다. 위젯은 웹 페이지나 웹 애플리케이션에서 사용자와 상호작용할 수 있는 부분으로, 버튼, 텍스트 상자, 슬라이더, 체크박스, 드롭다운 목록 등과 같은 다양한 형태가 있다.
# 웹 위젯은 주로 HTML, CSS 및 JavaScript를 사용하여 만들어지며, 웹 개발자들은 웹 페이지나 애플리케이션을 개발할 때 위젯을 설계하고 구현한다. 위젯은 사용자 경험을 개선하고 웹 애플리케이션의 기능을 확장하는 데 중요한 역할을 한다. 이를 사용하면 데이터 시각화, 파라미터 조절, 실험 및 모델 튜닝과 같은 작업을 보다 직관적으로 수행할 수 있다.
#
# 2. 대화형 상호작용: 위젯을 사용하여 사용자와 상호작용하는 웹 기반 사용자 인터페이스를 만들 수 있다. 이를 통해 사용자는 데이터를 필터링하거나 그래프를 업데이트하거나 알고리즘의 입력 매개변수를 조절하는 등의 작업을 쉽게 수행할 수 있다.
#
# 3. 주피터 노트북 통합: ipywidgets는 주피터 노트북과 통합되어 사용자가 노트북 셀 안에서 직접 위젯을 생성하고 조작할 수 있도록 한다.
#
# 4. 커스터마이즈 가능: 위젯은 사용자의 요구에 맞게 커스터마이즈할 수 있다. 스타일링, 레이아웃 및 동작을 조정하여 사용자 경험을 개선할 수 있다.
#
# 5. 이벤트 처리: 위젯은 이벤트 처리를 지원하며, 사용자의 상호작용에 따라 콜백 함수를 호출하여 데이터나 그래프를 업데이트할 수 있다.
#
# ipywidgets는 데이터 과학자, 연구자 및 개발자에게 데이터 분석 및 시각화 작업을 보다 직관적이고 대화형으로 수행할 수 있는 강력한 도구다. 주피터 노트북과 함께 사용하면 빠르게 실험하고 결과를 공유하며 협업할 수 있는 환경을 제공한다.

# %% [markdown]
# ipywidgets 모듈에서 interact 함수는 대화형 위젯을 생성하는데 사용되는 중요한 함수 중 하나다. 이 함수는 주피터 노트북에서 특히 유용하며, 함수 데코레이터나 매개변수로 사용하여 함수를 호출할 때 인터랙티브한 위젯을 생성한다. interact 함수를 사용하면 함수의 매개변수를 조절하면서 함수의 결과를 실시간으로 확인할 수 있다.

# %%
import matplotlib.pyplot as plt
from ipywidgets import interact

# %%
#covid image가 더 많지만, 균일하게 이미지를 보기위해서 작은이미지 기준으로 indexing을 하기위해 min을 해준다.
min_num_files = min(len(normals_list), len(covids_list))
print(min_num_files)
# Out:
# 2084

# %%
@interact(index=(0, min_num_files-1)) #slide bar 생성 0번부터 4068번 index까지 이동하게 된다.
def show_samples(index=0):
    normal_image = get_RGB_image(data_dir, normals_list[index])
    covid_image = get_RGB_image(data_dir, covids_list[index])
    
    plt.figure(figsize=(12,8))
    plt.subplot(121)
    plt.title('Normal')
    plt.imshow(normal_image)
    
    plt.subplot(122)
    plt.title('Covid')
    plt.imshow(covid_image)
# Out:
# interactive(children=(IntSlider(value=0, description='index', max=2083), Output()), _dom_classes=('widget-inte…

# %% [markdown]
# # 학습데이터셋 클래스 구축
#
# dataset instance를 생성될때
# 즉, data를 load하는 dataset은 기본적인 attribute를 가진다.
# 1. 생성자
#
# data_dir, transformer은 인자값, 총 변수는 5개다 self는 class 내에서는 공통적으로 호출될수 있는 변수이고, self가 아닌것은 class 내부에서만 사용된다.
#
# transformer은 none으로 한것은 향후에 이미지를 tensor로 변환하고 augmentation기법을 적용할때 transformer로 instance를 전달한다.
#
# 2. 데이터셋 길이
# 3. 데이터셋에 호출하는 인덱스에 맞는 아이템. 즉, return값은 이미지와 타겟값

# %%
import torch

# %%
train_data_dir = 'D:/covid/train'
class_list= ['normal', 'covid']

# %%
class Chest_dataset():
    def __init__(self, data_dir, transformer=None): 
        self.data_dir = data_dir
        normals = list_image_files(data_dir, 'normal') #하위폴더에 있는 이미지 파일을 불러들어오는 함수
        covids = list_image_files(data_dir, 'covid')
        
        self.files_path = normals + covids #각 파일의 list를 모두 더한것
        self.transformer = transformer
    
    def __len__(self):
        return len(self.files_path)
        
    def __getitem__(self, index): 
        image_file = os.path.join(self.data_dir, self.files_path[index])
        image =cv2.imread(image_file)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #index를 호출하면 그에맞는 image와 label을 반환하는 함수다. 해당인덱스 해당하는 파일의 경로를 설정을 하고 open cv의 함수로 이미지의 파일을 불러온다 그다음 BGR을 RGB로 변환한다.
        #타겟값은 class list의 해당하는 index값으로 받게된다. calss name을 정하고이미지 파일을 불러오고온다. 
        #폴더 하위의 이미지 데이터가 있었으니까 이미지 파일을 os.sep으로 분리를 해주고 첫번째 값을 class_name으로 설정한것이다.
        #calss name을 class list에서 대응하는 class index로 받아주게되면 class_id로 지정을 할 수있다.
        #normal인경우에는 class id가 0이 된다.
        
        class_name = self.files_path[index].split(os.sep)[0]
        class_id = class_list.index(class_name)
        
        #추후에 transformer을 하면 tensor형으로 변형이 되기때문에 변환을 해준다.
        #class id는 tensor로 바꾸고 long(int)값으로 변환해서 반환한다.
        if self.transformer:
            image = self.transformer(image)
            class_id = torch.Tensor([class_id]).long()
        
        return image, class_id
        #print(class_name, class_id)
        #print(class_name)
        
        #image filep path경로 확인
        #print(self.data_dir, self.files_path[index])
        #print(self.files_path[index].split(os.sep)[0])
        
        #target = class_list.index

# %%
dset = Chest_dataset(data_dir=train_data_dir)

# %%
image, target = dset[0]

# %%
#rgb 3채널, 높이와 너비가 1024, 0번 normal에 대응하는 이미지다.
print(image.shape)
print(target)
# Out:
# (1024, 1024, 3)
# 0

# %%
index = 0
image, target = dset[index]

plt.title(class_list[target])
plt.imshow(image)

# %%
index = -10
image, target = dset[index]

plt.title(class_list[target])
plt.imshow(image)

# %%
#Normal:3022, Covid:2084
len(dset)
# Out:
# 5106

# %%
print(image.shape)
# Out:
# (2539, 3050, 3)

# %% [markdown]
# # 연산가능한 텐서형으로 데이터 변환하기
#
# 이미지를 tensor형으로 변환하고, 이미지 크기를 224,224로 바꾸고 0과 1사이의 텐서값들을 평균과 표준편차의 값으로 정규화를 수행해준다. 3개가 들어가는 이유는 각각 rgb에 해당하는 값이다.

# %%
from torchvision import transforms

# %%
#tensor형 변환 전 (transformer 전) : 가로, 세로, RGB채널수
dset = Chest_dataset(data_dir = train_data_dir)
index = 200
image = dset[index][0]
target = dset[index][1]
print(image.shape)
print(target)
# Out:
# (1024, 1024, 3)
# 0

# %%
image
# Out:
# array([[[  3,   3,   3],
#         [  5,   5,   5],
#         [  5,   5,   5],
#         ...,
#         [ 71,  71,  71],
#         [ 81,  81,  81],
#         [ 48,  48,  48]],
#
#        [[  6,   6,   6],
#         [ 10,  10,  10],
#         [ 10,  10,  10],
#         ...,
#         [143, 143, 143],
#         [162, 162, 162],
#         [ 96,  96,  96]],
#
#        [[  5,   5,   5],
#         [  9,   9,   9],
#         [  9,   9,   9],
#         ...,
#         [126, 126, 126],
#         [144, 144, 144],
#         [ 86,  86,  86]],
#
#        ...,
#
#        [[ 33,  33,  33],
#         [ 63,  63,  63],
#         [ 65,  65,  65],
#         ...,
#         [ 98,  98,  98],
#         [ 90,  90,  90],
#         [ 46,  46,  46]],
#
#        [[ 35,  35,  35],
#         [ 66,  66,  66],
#         [ 68,  68,  68],
#         ...,
#         [100, 100, 100],
#         [ 90,  90,  90],
#         [ 47,  47,  47]],
#
#        [[ 17,  17,  17],
#         [ 31,  31,  31],
#         [ 34,  34,  34],
#         ...,
#         [ 48,  48,  48],
#         [ 42,  42,  42],
#         [ 22,  22,  22]]], dtype=uint8)

# %%
transformer = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize((224,224)),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# %%
#tensor형 변환 후 (transformer 후) : 텐서형이기 떄문에 torch로 변했다.
train_dset = Chest_dataset(train_data_dir, transformer)
index = 200
image = train_dset[index][0]
target = train_dset[index][1]
print(image.shape)
print(target)
# Out:
# torch.Size([3, 224, 224])
# tensor([0])
# C:\Users\82103\anaconda3\Lib\site-packages\torchvision\transforms\functional.py:1603: UserWarning: The default value of the antialias parameter of all the resizing transforms (Resize(), RandomResizedCrop(), etc.) will change from None to True in v0.17, in order to be consistent across the PIL and Tensor backends. To suppress this warning, directly pass antialias=True (recommended, future default), antialias=None (current default, which means False for Tensors and True for PIL), or antialias=False (only works on Tensors - PIL will still use antialiasing). This also applies if you are using the inference transforms from the models weights: update the call to weights.transforms(antialias=True).
#   warnings.warn(

# %%
image
# Out:
# tensor([[[-0.9277, -0.9299, -0.9335,  ..., -0.4331, -0.2633,  0.0474],
#          [-0.9473, -0.9479, -0.9526,  ..., -0.6801, -0.5468, -0.2935],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.8079, -0.7113, -0.5315],
#          ...,
#          [-0.4853, -0.2719, -0.0711,  ..., -0.4347, -0.2637, -0.1294],
#          [-0.4790, -0.3036, -0.1128,  ..., -0.4519, -0.2937, -0.1691],
#          [-0.4885, -0.2834, -0.1013,  ..., -0.4671, -0.3059, -0.2422]],
#
#         [[-0.9277, -0.9299, -0.9335,  ..., -0.4331, -0.2633,  0.0474],
#          [-0.9473, -0.9479, -0.9526,  ..., -0.6801, -0.5468, -0.2935],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.8079, -0.7113, -0.5315],
#          ...,
#          [-0.4853, -0.2719, -0.0711,  ..., -0.4347, -0.2637, -0.1294],
#          [-0.4790, -0.3036, -0.1128,  ..., -0.4519, -0.2937, -0.1691],
#          [-0.4885, -0.2834, -0.1013,  ..., -0.4671, -0.3059, -0.2422]],
#
#         [[-0.9277, -0.9299, -0.9335,  ..., -0.4331, -0.2633,  0.0474],
#          [-0.9473, -0.9479, -0.9526,  ..., -0.6801, -0.5468, -0.2935],
#          [-0.9529, -0.9529, -0.9529,  ..., -0.8079, -0.7113, -0.5315],
#          ...,
#          [-0.4853, -0.2719, -0.0711,  ..., -0.4347, -0.2637, -0.1294],
#          [-0.4790, -0.3036, -0.1128,  ..., -0.4519, -0.2937, -0.1691],
#          [-0.4885, -0.2834, -0.1013,  ..., -0.4671, -0.3059, -0.2422]]])

# %% [markdown]
# # 데이로더 구현하기
# #drop_last은 batch_size에 따라서 남은 데이터를 버릴지 말지 결정한다.
# #validation은 batch를 크게 묶어도, 작게묶어도 상관이없다. 학습에는 영향이 없으니까 상관이없다!

# %%
from torch.utils.data import DataLoader

# %%
train_data_dir = 'D:/covid/train/'
val_data_dir = 'D:/covid/test/'

train_dset = Chest_dataset(train_data_dir, transformer)
train_dloader = DataLoader(train_dset, batch_size=32, shuffle=True, drop_last=True) 
val_dset = Chest_dataset(val_data_dir, transformer)
val_dloader = DataLoader(val_dset, batch_size=32, shuffle=False)

# %%
#두번쨰 방법 : #dict형태의 dataloaders라는 변수에 train과 val라는 key를 주어준다. 이것으로 dataloader를 한번에 반환한다.
def build_dataloader(train_data_dir, val_data_dir):
    dataloaders = {} 
    train_dset = Chest_dataset(train_data_dir, transformer)
    dataloaders['train'] = DataLoader(train_dset, batch_size=32, shuffle=True, drop_last=True) 
    val_dset = Chest_dataset(val_data_dir, transformer)
    dataloaders['val'] = DataLoader(val_dset, batch_size=32, shuffle=False)
    
    return dataloaders

# %%
train_data_dir = 'D:/covid/train/'
val_data_dir = 'D:/covid/test/'
dataloaders = build_dataloader(train_data_dir, val_data_dir)

# %%
print(dataloaders)
# Out:
# {'train': <torch.utils.data.dataloader.DataLoader object at 0x0000027968A67E50>, 'val': <torch.utils.data.dataloader.DataLoader object at 0x0000027968A67F50>}

# %% [markdown]
# # Classification 모델 불러오기 (vgg19) 및 summary
#
# summary : https://lynnshin.tistory.com/54
#
# - torchsummy : densenet안됌
# - torchsummyX : densenet은 가능하지만, 모델을 cuda에 올리면 안됌(model.to(device))
# - torchinfo : head부분을 수정했는데 안됌

# %%
from torchvision import models

# %%
device = torch.device('cuda' if torch.cuda.is_available else 'cpu')

# %%
device
# Out:
# device(type='cuda')

# %%
model = models.vgg19(pretrained=True)
# Out:
# C:\Users\82103\anaconda3\Lib\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\82103\anaconda3\Lib\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): ReLU(inplace=True)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): ReLU(inplace=True)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): ReLU(inplace=True)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): ReLU(inplace=True)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): ReLU(inplace=True)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): ReLU(inplace=True)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): ReLU(inplace=True)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=25088, out_features=4096, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=4096, out_features=4096, bias=True)
#     (4): ReLU(inplace=True)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Linear(in_features=4096, out_features=1000, bias=True)
#   )
# )

# %%
#pip install torchsummary

# %%
from torchsummary import summary

# %%
model = model.to(device)

# %%
summary(model, (3,224,224), batch_size=32) #입력 이미지의 (rgb채널, 높이, 가로폭의 픽셀크기), batch_size의 디폴트값은 1이다.
# output Shape  은 batch_size부터 layer들이 나타난다.
#batch_size를 줄이면 메모리 공간이 줄어든다.
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [32, 64, 224, 224]           1,792
#               ReLU-2         [32, 64, 224, 224]               0
#             Conv2d-3         [32, 64, 224, 224]          36,928
#               ReLU-4         [32, 64, 224, 224]               0
#          MaxPool2d-5         [32, 64, 112, 112]               0
#             Conv2d-6        [32, 128, 112, 112]          73,856
#               ReLU-7        [32, 128, 112, 112]               0
#             Conv2d-8        [32, 128, 112, 112]         147,584
#               ReLU-9        [32, 128, 112, 112]               0
#         MaxPool2d-10          [32, 128, 56, 56]               0
#            Conv2d-11          [32, 256, 56, 56]         295,168
#              ReLU-12          [32, 256, 56, 56]               0
#            Conv2d-13          [32, 256, 56, 56]         590,080
#              ReLU-14          [32, 256, 56, 56]               0
#            Conv2d-15          [32, 256, 56, 56]         590,080
#              ReLU-16          [32, 256, 56, 56]               0
#            Conv2d-17          [32, 256, 56, 56]         590,080
#              ReLU-18          [32, 256, 56, 56]               0
#         MaxPool2d-19          [32, 256, 28, 28]               0
#            Conv2d-20          [32, 512, 28, 28]       1,180,160
#              ReLU-21          [32, 512, 28, 28]               0
#            Conv2d-22          [32, 512, 28, 28]       2,359,808
#              ReLU-23          [32, 512, 28, 28]               0
#            Conv2d-24          [32, 512, 28, 28]       2,359,808
#              ReLU-25          [32, 512, 28, 28]               0
#            Conv2d-26          [32, 512, 28, 28]       2,359,808
#              ReLU-27          [32, 512, 28, 28]               0
#         MaxPool2d-28          [32, 512, 14, 14]               0
#            Conv2d-29          [32, 512, 14, 14]       2,359,808
#              ReLU-30          [32, 512, 14, 14]               0
#            Conv2d-31          [32, 512, 14, 14]       2,359,808
#              ReLU-32          [32, 512, 14, 14]               0
#            Conv2d-33          [32, 512, 14, 14]       2,359,808
#              ReLU-34          [32, 512, 14, 14]               0
#            Conv2d-35          [32, 512, 14, 14]       2,359,808
#              ReLU-36          [32, 512, 14, 14]               0
#         MaxPool2d-37            [32, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [32, 512, 7, 7]               0
#            Linear-39                 [32, 4096]     102,764,544
#              ReLU-40                 [32, 4096]               0
#           Dropout-41                 [32, 4096]               0
#            Linear-42                 [32, 4096]      16,781,312
#              ReLU-43                 [32, 4096]               0
#           Dropout-44                 [32, 4096]               0
#            Linear-45                 [32, 1000]       4,097,000
# ================================================================
# Total params: 143,667,240
# Trainable params: 143,667,240
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 7637.99
# Params size (MB): 548.05
# Estimated Total Size (MB): 8204.42
# ----------------------------------------------------------------

# %% [markdown]
# Total params: 20,156,226
# Trainable params: 20,156,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 7626.06
# Params size (MB): 76.89
# Estimated Total Size (MB): 7721.33
# -----------------------------------------

# %% [markdown]
# # 데이터에 맞도록 모델 Head 부분 변경하기

# %%
import torch.nn as nn

# %% [markdown]
# AdptiveAvgPool
#
# 8 * 8 -> abgpool(output_size=(2,2)) -> (2.2)
# 20 * 20 -> abgpool(output_size=(2,2)) -> (2.2)

# %%
# output size를 지정하면 어떠한 입력값이 와도 지정한 output size로 데이터 pooling을 수행한다.
'''
kernel_size를 줄이는 방법은 옳지 않았따.
model.features[21] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[23] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[25] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[28] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[30] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[32] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
model.features[34] = nn.Conv2d(in_channels=512, out_channels=512, kernel_size=1, stride=1, padding=1)
22 24 26 29 31 33 35 을 다른 함수로 바꿔보자
'''
model.features[22] = nn.CELU()
model.features[24] = nn.CELU()
model.features[26] = nn.CELU()
model.features[29] = nn.CELU()
model.features[31] = nn.CELU()
model.features[33] = nn.CELU()
model.features[35] = nn.CELU()
model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
model.classifier = nn.Sequential(
    nn.Flatten(),
    nn.Linear(512, 256),
    nn.ReLU(),
    nn.Dropout(0.1), #네트워크 가중치 편향을 막기 위해 사용
    nn.Linear(256,2),
    nn.Sigmoid()
)

# %%
def build_vgg19_based_model(device='cuda'):

    model.avgpool = nn.AdaptiveAvgPool2d(output_size=(1,1))
    model.classifier = nn.Sequential(
        nn.Flatten(),
        nn.Linear(512, 256),
        nn.ReLU(),
        #nn.Dropout(0.1), #네트워크 가중치 편향을 막기 위해 사용
        nn.Linear(256,2),
        nn.Sigmoid() #binary class를 예측할땐 sigmoid, 다중 분류 예측에는 softmax
    )
    return model.to(device) #작성된 모델을 cuda로 지정된 torch device에 mount하라는 뜻이다. 이것은 gpu 연산을 가능하게한다.

# %%
model = build_vgg19_based_model(device='cuda')

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): CELU(alpha=1.0)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): CELU(alpha=1.0)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): CELU(alpha=1.0)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): CELU(alpha=1.0)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): CELU(alpha=1.0)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): CELU(alpha=1.0)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): CELU(alpha=1.0)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=2, bias=True)
#     (4): Sigmoid()
#   )
# )

# %%
summary(model, (3,224,224), batch_size=32, device='cuda')
# total parameter즉, parameter size가 줄었다.
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [32, 64, 224, 224]           1,792
#               ReLU-2         [32, 64, 224, 224]               0
#             Conv2d-3         [32, 64, 224, 224]          36,928
#               ReLU-4         [32, 64, 224, 224]               0
#          MaxPool2d-5         [32, 64, 112, 112]               0
#             Conv2d-6        [32, 128, 112, 112]          73,856
#               ReLU-7        [32, 128, 112, 112]               0
#             Conv2d-8        [32, 128, 112, 112]         147,584
#               ReLU-9        [32, 128, 112, 112]               0
#         MaxPool2d-10          [32, 128, 56, 56]               0
#            Conv2d-11          [32, 256, 56, 56]         295,168
#              ReLU-12          [32, 256, 56, 56]               0
#            Conv2d-13          [32, 256, 56, 56]         590,080
#              ReLU-14          [32, 256, 56, 56]               0
#            Conv2d-15          [32, 256, 56, 56]         590,080
#              ReLU-16          [32, 256, 56, 56]               0
#            Conv2d-17          [32, 256, 56, 56]         590,080
#              ReLU-18          [32, 256, 56, 56]               0
#         MaxPool2d-19          [32, 256, 28, 28]               0
#            Conv2d-20          [32, 512, 28, 28]       1,180,160
#              ReLU-21          [32, 512, 28, 28]               0
#            Conv2d-22          [32, 512, 28, 28]       2,359,808
#              CELU-23          [32, 512, 28, 28]               0
#            Conv2d-24          [32, 512, 28, 28]       2,359,808
#              CELU-25          [32, 512, 28, 28]               0
#            Conv2d-26          [32, 512, 28, 28]       2,359,808
#              CELU-27          [32, 512, 28, 28]               0
#         MaxPool2d-28          [32, 512, 14, 14]               0
#            Conv2d-29          [32, 512, 14, 14]       2,359,808
#              CELU-30          [32, 512, 14, 14]               0
#            Conv2d-31          [32, 512, 14, 14]       2,359,808
#              CELU-32          [32, 512, 14, 14]               0
#            Conv2d-33          [32, 512, 14, 14]       2,359,808
#              CELU-34          [32, 512, 14, 14]               0
#            Conv2d-35          [32, 512, 14, 14]       2,359,808
#              CELU-36          [32, 512, 14, 14]               0
#         MaxPool2d-37            [32, 512, 7, 7]               0
# AdaptiveAvgPool2d-38            [32, 512, 1, 1]               0
#           Flatten-39                  [32, 512]               0
#            Linear-40                  [32, 256]         131,328
#              ReLU-41                  [32, 256]               0
#            Linear-42                    [32, 2]             514
#           Sigmoid-43                    [32, 2]               0
# ================================================================
# Total params: 20,156,226
# Trainable params: 20,156,226
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 18.38
# Forward/backward pass size (MB): 7626.00
# Params size (MB): 76.89
# Estimated Total Size (MB): 7721.27
# ----------------------------------------------------------------

# %% [markdown]
# # 손실함수 (Cross Entropy)

# %% [markdown]
# classification의 경우으넨 0과 1사이의 값을 가지게 된다. binary crossentropy의 겨웅에도 베르누이 확률 분포를 따르기 때문에 y는 0과 1이 들어가고, y_pred는 모델의 결과값이 된다.
# Loss = (Y)(-log(Y_pred)) + (1-Y)(-log(1-Y_pred))
# y가 target값이 1일때는 전체수식에서 앞에 항만 남고, 뒤에 항은 1-y가 0이 되기 때문에 제거된다. 반대로 y가 0의값을 가지게 될때 앞의 값은 제거되고, 뒤에 수식만 남게된다. 이때 y_pred값은 어떻게 이동해야할까?
#
# https://pyimagesearch.com/2021/01/18/contrastive-loss-for-siamese-networks-with-keras-and-tensorflow/

# %%
loss_func = nn.CrossEntropyLoss(reduction='mean') 
#reduction y와 y_pred는 미니배치에 대한 평균을 계산을 해서 loss의 값을 return해주는것이다.

# %% [markdown]
# # SGDM (Stochastic Gradient Descent with Momentum) Optimization

# %% [markdown]
# y축은 error, x축으s weight space를 가진다고할때, 모델의 파라미터는 error(loss fuction)을 최소화 하는방향으로 기울기를 하강시키기 위해 weight space를 탐색한다. 이론적으로는 local minima가 아닌 global minia를 찾는것이 opitmization이다.
# local minima가 global minima인지 아닌지 딜레마에 빠질수 있는데, Momentum을 통해서 다른 더 낮은 local minima가 있는지 탐색하는 방법이 SGDM이다. momentum의 default 값은0이다.
#
# ** GD(Gradient Descent)와 SGD(Stochastic Gradient Descent)의 차이는 무엇일까?
#
# - GD(Gradient Descent)는 모든 데이터에 대해서 학습을 하려고 하기때문에 모든 방향성을 보두 고려해서 error를 최소화하는 weight space를 탐색한다. 이럴 경우에는 근처에 있는 극소점에 도달하기 때문에 local minima에 빠지기 쉽다.
#
# - SGD(Stochastic Gradient Descent)의 경우는 모든 데이터가 아닌 일부 데이터를 뽑아서 데이터를 학습하기 때문에 모든 방향이 아닌 일부 방향에 대해서 학습하게된다. 이때 일부 데이터의 개수는 batch_size가 된다. 이에따라 학습시간은 줄어들고 local minima에 빠질 확률이 줄어든다. 이때, momentum을 이용하면 다른 극소점까지 탐색하기 때문에 global minima에 도달할 확률이 커지게 된다.

# %%
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %% [markdown]
# # 모델 학습을 위한 함수 구현하기

# %%
device = torch.device('cuda')

# %%
# 한번 iteration할때 train과 validation이 동작을 한다. 한번 epoch할떄 train한번, epoch한번 돌아서 loss를 반환을 하고 그 loss를 토대로 overfitting이 되는지 한단한다.
def train_one_epoch(dataloaders, model, optimizer, loss_func, device):
    loss ={}
    
    for phase in["train", "val"]: 
        running_loss = 0.0 
        #중간 중간 loss를 확인하기 위해서 필요하다. 중간중간에 running loss를 받아와서 print문으로 출력해서 잘 학습이 되는지 확인할 수 있게한다.
        
        if phase == "train":
            model.train()
        else:
            model.eval() 
            #모델내 btach normalizization나 dropout등을 activation 할지말지 구별한다. 즉, train과 validation set에서 다르게 작동하는 layer가 있기 때문에 이를 구별하기위해 사용한다.
            
        for index, batch in enumerate(dataloaders[phase]): #dataloaders를 phase에 맞게 불러오고 index값과 batch형태로 iterative하게 가져온다. batch는 엄밀히 말하면 mini_batch다.
            image = batch[0].to(device) #image 
            label = batch[1].to(device) #label 위에선 class id normal이면 0 covid면1
            
            
            """
            with torch.no_grad(): 는 valid일때, set_grad_enabled는 tarin일떄 사용한다.
            다음 코드는 밑에 with torch.set_grad_enabled(phase =="train"):와 같다.
            if phase == 'train':
                prediction = model(image)
            elif phase == 'val':
                woth torch.no_grad():
                    prediction = model(image)
            """
            
            with torch.set_grad_enabled(phase =="train"):
                prediction = model(image)
                loss = loss_func(prediction, target)
                
                if phase == "train":
                    optimizer.zero_grad() #loss를 계산하고, loss에 대해서 optimizer의 weight값을 업데이트 할때, optimizer에 zero_grad를 안해주면 미분의 누적값들이 계속 생기게 된다. 따라서 학습이 원하는 방향으로 진행이 되지 않을수 있다. 그렇기 때문에 loss를 기반으로 optimizer를 수행하기전에 미분함수의 파라미터에 들어있는 모든 gradient를 0으로 만들어주고 그다음 loss에 해당하는 파라미터의 기울기 값을 다시 갱신을 해주고 다시 optimizer를 수행한다.
                    loss.backward() #loss가 구해지면 model의 파라미터의 gradient를 추적할수 있는 기능이 있는데 loss.backward()를 통해 loss값에 관련이 있는 모든 model의 파라미터의 미분값이 업데이트 되게 된다.
                    optimizer.step() #이 미분값을 optimizer에 전달하게되고, 가중치를 미리 설정한 수식에 따라서 가중치와 learning rate를 토대로 모델의 weight값을 갱신하게 된다. loss를 가지고 optimizer을 수행한다.
                    
            running_loss += loss.item() #loss 값의 value만 받아서 아까 설정한 running_loss에 누적을 시켜준다.
                            
                #index 10번 주기의 간격으로 running loss를 출력을 해라라는 의미다.
            if phase == "train":
                if index % 10 == 0:
                    print(f"{index}/{len(dataloaders['train'])} - Running loss: {loss.item()}")#running_loss의 값은 최종적으로 dataloader의 개수(batch크기의 평균한 값)을 계산하고 각 phase의 key값에 전달해준다.
                    
        losses[phase] = running_loss / len(dataloader[phase])
        
    return losses

# %% [markdown]
# # 모델검증을 위한 accuracy 생성하기
# - Top-1 accuracy
#     - 가장 confidence가 높은 예측값의 클래스가 ground turth와 일치하는 경우 True-Positive로 판단
# - Top-5 accuracy
#     - confidence가 높은 상위 5개 예측값의 클래스가 ground turth와 존재하는 경우 True-Positive로 판단

# %%
import numpy

# %%
@torch.no_grad()
def get_accuracy(image, target, model):
    batch_size = image.shape[0] #이미지에서 batch크기를 계산을 하고 이미지를 연산을 해서 output값에 넣어준다
    prediction = model(image) # prediction값은 (batch_size, num_classes)이다. 
    #예를들어 이때 각 class마다 [B, 0]: 0,1, [B,1]:0.2, [B,2]:0.7
    _, pred_label = torch.max(prediction, dim=1) # dimension 1을 기준으로 max값을 구한다.위의 경우에서 (B,1) -> pred_label =2
    is_correct = (pred_label == target) #pred_label과 target을 매칭하여 True/ False를 반환
    accuracy = is_correct.cpu().numpy().sum() / batch_size #True, False를 모두 더하면 false는0 true는 1로 대변이 된다. 이것을 batch_size로 나눈다.
    return accuracy

#accuracy를 함수로 작성한 이유는 매 iteration, epoch에 train과 validation에 대해서 매번 accuracy를 연산을 하고, 개선되는 과정을 살펴 볼것이기 때문에 이 함수가 반복적으로 호출되기 위해 함수를짯다.
#accuracy가 계산되는 과정에서는 backward과정이 필요없기 때문에 decorater까지 넣어주어 model의 파라미터에 대해서 gradient update 과정을 꺼준다.

# %% [markdown]
# # 모델 학습 수행하기

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_data_dir = 'D:/covid/train/'
val_data_dir = 'D:/covid/test/'
dataloaders = build_dataloader(train_data_dir, val_data_dir)
model = build_vgg19_based_model(device='cuda')
loss_func = nn.CrossEntropyLoss(reduction='mean')
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
# 한번 iteration할때 train과 validation이 동작을 한다. 한번 epoch할떄 train한번, epoch한번 돌아서 loss를 반환을 하고 그 loss를 토대로 overfitting이 되는지 한단한다.
def train_one_epoch(dataloader, model, optimizer, loss_function, device):
    losses = {}
    accuracies = {}
    
    for phase in["train", "val"]: 
        running_loss = 0.0
        running_correct = 0.0
        #중간 중간 loss를 확인하기 위해서 필요하다. 중간중간에 running loss를 받아와서 print문으로 출력해서 잘 학습이 되는지 확인할 수 있게한다.
        
        if phase == "train":
            model.train()
        else:
            model.eval() 
            #모델내 btach normalizization나 dropout등을 activation 할지말지 구별한다. 즉, train과 validation set에서 다르게 작동하는 layer가 있기 때문에 이를 구별하기위해 사용한다.
            
        for index, batch in enumerate(dataloader[phase]): #dataloaders를 phase에 맞게 불러오고 index값과 batch형태로 iterative하게 가져온다. batch는 엄밀히 말하면 mini_batch다.
            image = batch[0].to(device) #image 
            label = batch[1].squeeze(dim=1).to(device) #label 위에선 class id normal이면 0 covid면1
            
            with torch.set_grad_enabled(phase =="train"):
                prediction = model(image)
                loss = loss_func(prediction, label)
                
                optimizer.zero_grad()
                
                if phase == "train":
                    #optimizer.zero_grad() #loss를 계산하고, loss에 대해서 optimizer의 weight값을 업데이트 할때, optimizer에 zero_grad를 안해주면 미분의 누적값들이 계속 생기게 된다. 따라서 학습이 원하는 방향으로 진행이 되지 않을수 있다. 그렇기 때문에 loss를 기반으로 optimizer를 수행하기전에 미분함수의 파라미터에 들어있는 모든 gradient를 0으로 만들어주고 그다음 loss에 해당하는 파라미터의 기울기 값을 다시 갱신을 해주고 다시 optimizer를 수행한다.
                    loss.backward() #loss가 구해지면 model의 파라미터의 gradient를 추적할수 있는 기능이 있는데 loss.backward()를 통해 loss값에 관련이 있는 모든 model의 파라미터의 미분값이 업데이트 되게 된다.
                    optimizer.step() #이 미분값을 optimizer에 전달하게되고, 가중치를 미리 설정한 수식에 따라서 가중치와 learning rate를 토대로 모델의 weight값을 갱신하게 된다. loss를 가지고 optimizer을 수행한다.
                    
            running_loss += loss.item() #loss 값의 value만 받아서 아까 설정한 running_loss에 누적을 시켜준다.
            running_correct += get_accuracy(image, label, model)
                            
                #index 10번 주기의 간격으로 running loss를 출력을 해라라는 의미다.
            if phase == "train":
                if index % 10 == 0:
                    print(f"{index}/{len(dataloaders['train'])} - Running loss: {loss.item()}")#running_loss의 값은 최종적으로 dataloader의 개수(batch크기의 평균한 값)을 계산하고 각 phase의 key값에 전달해준다.
                    
        losses[phase] = running_loss / len(dataloader[phase])
        accuracies[phase] = running_correct / len(dataloader[phase])
    return losses, accuracies

# %%
-
# Out:
#   Cell In[56], line 1
#     -
#      ^
# SyntaxError: invalid syntax

# %%
model
# Out:
# VGG(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (3): ReLU(inplace=True)
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (6): ReLU(inplace=True)
#     (7): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (8): ReLU(inplace=True)
#     (9): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU(inplace=True)
#     (12): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU(inplace=True)
#     (14): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (15): ReLU(inplace=True)
#     (16): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (17): ReLU(inplace=True)
#     (18): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (19): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (20): ReLU(inplace=True)
#     (21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (22): CELU(alpha=1.0)
#     (23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (24): CELU(alpha=1.0)
#     (25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (26): CELU(alpha=1.0)
#     (27): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (29): CELU(alpha=1.0)
#     (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (31): CELU(alpha=1.0)
#     (32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (33): CELU(alpha=1.0)
#     (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (35): CELU(alpha=1.0)
#     (36): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (classifier): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=512, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=2, bias=True)
#     (4): Sigmoid()
#   )
# )

# %%
num_epochs = 40

best_acc = 0.0
train_loss, train_acc = [], []
val_loss, val_acc = [], []

for epoch in range(num_epochs):
    losses, accuracies = train_one_epoch(dataloaders, model, optimizer, loss_func, device)
    train_loss.append(losses['train'])
    train_acc.append(accuracies['train'])
    val_loss.append(losses['val'])
    val_acc.append(accuracies['val'])
    
    print(f"{epoch+1}/{num_epochs}-Train loss:{losses['train']}, Val loss:{losses['val']}")
    print(f"{epoch+1}/{num_epochs}-Train acc:{accuracies['train']}, Val acc:{accuracies['val']}")
    
    if accuracies['val'] > best_acc:
        best_acc = accuracies['val']
        torch.save(model.state_dict(), f"vgg19_celu_avgpool1_epoch40_model_{epoch}.pth")
# Out:
# 0/159 - Running loss: 0.6902482509613037
# 10/159 - Running loss: 0.6830141544342041
# 20/159 - Running loss: 0.692075252532959
# 30/159 - Running loss: 0.7042301893234253
# 40/159 - Running loss: 0.6717147827148438
# 50/159 - Running loss: 0.6600571870803833
# 60/159 - Running loss: 0.5752208232879639
# 70/159 - Running loss: 0.5170068740844727
# 80/159 - Running loss: 0.609614908695221
# 90/159 - Running loss: 0.5296840667724609
# 100/159 - Running loss: 0.5930846333503723
# 110/159 - Running loss: 0.5882823467254639
# 120/159 - Running loss: 0.4973742365837097
# 130/159 - Running loss: 0.4734555184841156
# 140/159 - Running loss: 0.4905153512954712
# 150/159 - Running loss: 0.40663623809814453
# 1/40-Train loss:0.5742406569561869, Val loss:0.5203705694315568
# 1/40-Train acc:0.7285770440251572, Val acc:0.7816128447024673
# 0/159 - Running loss: 0.3846745789051056
# 10/159 - Running loss: 0.4576714038848877
# 20/159 - Running loss: 0.4204810559749603
# 30/159 - Running loss: 0.41419029235839844
# 40/159 - Running loss: 0.38510826230049133
# 50/159 - Running loss: 0.45159396529197693
# 60/159 - Running loss: 0.5065053105354309
# 70/159 - Running loss: 0.5059854388237
# 80/159 - Running loss: 0.5576211810112
# 90/159 - Running loss: 0.4324546456336975
# 100/159 - Running loss: 0.3865821361541748
# 110/159 - Running loss: 0.43073567748069763
# 120/159 - Running loss: 0.4810057282447815
# 130/159 - Running loss: 0.3916408121585846
# 140/159 - Running loss: 0.34709975123405457
# 150/159 - Running loss: 0.34422406554222107
# 2/40-Train loss:0.41976043038398214, Val loss:0.4663610261566234
# 2/40-Train acc:0.9040880503144654, Val acc:0.8428428882438317
# 0/159 - Running loss: 0.4280449450016022
# 10/159 - Running loss: 0.44039613008499146
# 20/159 - Running loss: 0.3861958384513855
# 30/159 - Running loss: 0.3581911623477936
# 40/159 - Running loss: 0.4143597483634949
# 50/159 - Running loss: 0.3838019073009491
# 60/159 - Running loss: 0.43236711621284485
# 70/159 - Running loss: 0.3871029317378998
# 80/159 - Running loss: 0.35606878995895386
# 90/159 - Running loss: 0.3893234431743622
# 100/159 - Running loss: 0.5147073864936829
# 110/159 - Running loss: 0.43113523721694946
# 120/159 - Running loss: 0.4322045147418976
# 130/159 - Running loss: 0.39568161964416504
# 140/159 - Running loss: 0.413349449634552
# 150/159 - Running loss: 0.3949557840824127
# 3/40-Train loss:0.39056755742936766, Val loss:0.45078012740836954
# 3/40-Train acc:0.9302279874213837, Val acc:0.8611665457184324
# 0/159 - Running loss: 0.37382304668426514
# 10/159 - Running loss: 0.3818858861923218
# 20/159 - Running loss: 0.4162079095840454
# 30/159 - Running loss: 0.3363175392150879
# 40/159 - Running loss: 0.32264506816864014
# 50/159 - Running loss: 0.3206273913383484
# 60/159 - Running loss: 0.4355219602584839
# 70/159 - Running loss: 0.3789132535457611
# 80/159 - Running loss: 0.3259458541870117
# 90/159 - Running loss: 0.31462186574935913
# 100/159 - Running loss: 0.3628219664096832
# 110/159 - Running loss: 0.3615984320640564
# 120/159 - Running loss: 0.3734099268913269
# 130/159 - Running loss: 0.31800323724746704
# 140/159 - Running loss: 0.3490752577781677
# 150/159 - Running loss: 0.3988077640533447
# 4/40-Train loss:0.3672702018194978, Val loss:0.44568260829403716
# 4/40-Train acc:0.9526336477987422, Val acc:0.8643867924528302
# 0/159 - Running loss: 0.3736794590950012
# 10/159 - Running loss: 0.3363015353679657
# 20/159 - Running loss: 0.37198606133461
# 30/159 - Running loss: 0.35029569268226624
# 40/159 - Running loss: 0.3268553614616394
# 50/159 - Running loss: 0.3764006793498993
# 60/159 - Running loss: 0.3456568121910095
# 70/159 - Running loss: 0.41827887296676636
# 80/159 - Running loss: 0.39785248041152954
# 90/159 - Running loss: 0.356587678194046
# 100/159 - Running loss: 0.38340291380882263
# 110/159 - Running loss: 0.33465737104415894
# 120/159 - Running loss: 0.3435192108154297
# 130/159 - Running loss: 0.38274672627449036
# 140/159 - Running loss: 0.3964580297470093
# 150/159 - Running loss: 0.43875598907470703
# 5/40-Train loss:0.3635604267225325, Val loss:0.42569668394214705
# 5/40-Train acc:0.9585298742138365, Val acc:0.8744103773584906
# 0/159 - Running loss: 0.37690412998199463
# 10/159 - Running loss: 0.36473211646080017
# 20/159 - Running loss: 0.37134379148483276
# 30/159 - Running loss: 0.31740495562553406
# 40/159 - Running loss: 0.4072358310222626
# 50/159 - Running loss: 0.33015692234039307
# 60/159 - Running loss: 0.365751177072525
# 70/159 - Running loss: 0.3527933657169342
# 80/159 - Running loss: 0.35122427344322205
# 90/159 - Running loss: 0.35355904698371887
# 100/159 - Running loss: 0.3336442708969116
# 110/159 - Running loss: 0.3165423274040222
# 120/159 - Running loss: 0.31657785177230835
# 130/159 - Running loss: 0.5196278095245361
# 140/159 - Running loss: 0.3650165796279907
# 150/159 - Running loss: 0.3292788565158844
# 6/40-Train loss:0.35540922932654806, Val loss:0.3924936995191394
# 6/40-Train acc:0.9624606918238994, Val acc:0.9157293178519593
# 0/159 - Running loss: 0.3478873074054718
# 10/159 - Running loss: 0.33755961060523987
# 20/159 - Running loss: 0.3444240987300873
# 30/159 - Running loss: 0.318316251039505
# 40/159 - Running loss: 0.34885844588279724
# 50/159 - Running loss: 0.3473040759563446
# 60/159 - Running loss: 0.3156748414039612
# 70/159 - Running loss: 0.31491875648498535
# 80/159 - Running loss: 0.34557032585144043
# 90/159 - Running loss: 0.334482878446579
# 100/159 - Running loss: 0.3230768144130707
# 110/159 - Running loss: 0.32230836153030396
# 120/159 - Running loss: 0.37344813346862793
# 130/159 - Running loss: 0.35758399963378906
# 140/159 - Running loss: 0.31705233454704285
# 150/159 - Running loss: 0.3427087664604187
# 7/40-Train loss:0.34679228535988044, Val loss:0.38695726079760856
# 7/40-Train acc:0.9705188679245284, Val acc:0.9245283018867925
# 0/159 - Running loss: 0.3264946937561035
# 10/159 - Running loss: 0.3951210677623749
# 20/159 - Running loss: 0.3571217358112335
# 30/159 - Running loss: 0.35045433044433594
# 40/159 - Running loss: 0.3327362537384033
# 50/159 - Running loss: 0.3183724582195282
# 60/159 - Running loss: 0.3528265953063965
# 70/159 - Running loss: 0.3383956551551819
# 80/159 - Running loss: 0.32026806473731995
# 90/159 - Running loss: 0.3481915593147278
# 100/159 - Running loss: 0.3268609642982483
# 110/159 - Running loss: 0.331975519657135
# 120/159 - Running loss: 0.4048655331134796
# 130/159 - Running loss: 0.3151003420352936
# 140/159 - Running loss: 0.33333659172058105
# 150/159 - Running loss: 0.31337934732437134
# 8/40-Train loss:0.3426092581928901, Val loss:0.4326445049834701
# 8/40-Train acc:0.9736635220125787, Val acc:0.8732311320754716
# 0/159 - Running loss: 0.3156721889972687
# 10/159 - Running loss: 0.33004170656204224
# 20/159 - Running loss: 0.3207962214946747
# 30/159 - Running loss: 0.3559521734714508
# 40/159 - Running loss: 0.31335997581481934
# 50/159 - Running loss: 0.40404993295669556
# 60/159 - Running loss: 0.3854903280735016
# 70/159 - Running loss: 0.3500676453113556
# 80/159 - Running loss: 0.3581942021846771
# 90/159 - Running loss: 0.34527093172073364
# 100/159 - Running loss: 0.34386250376701355
# 110/159 - Running loss: 0.36212337017059326
# 120/159 - Running loss: 0.31386226415634155
# 130/159 - Running loss: 0.3464168906211853
# 140/159 - Running loss: 0.3533391058444977
# 150/159 - Running loss: 0.3518792986869812
# 9/40-Train loss:0.3431966055489186, Val loss:0.399721308136886
# 9/40-Train acc:0.9760220125786163, Val acc:0.9068396226415094
# 0/159 - Running loss: 0.3824227750301361
# 10/159 - Running loss: 0.35206928849220276
# 20/159 - Running loss: 0.3706362545490265
# 30/159 - Running loss: 0.3271806836128235
# 40/159 - Running loss: 0.37066617608070374
# 50/159 - Running loss: 0.3432796001434326
# 60/159 - Running loss: 0.35257986187934875
# 70/159 - Running loss: 0.3134686052799225
# 80/159 - Running loss: 0.3138608932495117
# 90/159 - Running loss: 0.39169543981552124
# 100/159 - Running loss: 0.3486559987068176
# 110/159 - Running loss: 0.3237497806549072
# 120/159 - Running loss: 0.3162986636161804
# 130/159 - Running loss: 0.31543830037117004
# 140/159 - Running loss: 0.3304329216480255
# 150/159 - Running loss: 0.3283390402793884
# 10/40-Train loss:0.33722790119782936, Val loss:0.39125453751042205
# 10/40-Train acc:0.980935534591195, Val acc:0.9168632075471698
# 0/159 - Running loss: 0.31506866216659546
# 10/159 - Running loss: 0.35151809453964233
# 20/159 - Running loss: 0.3148419260978699
# 30/159 - Running loss: 0.3296549618244171
# 40/159 - Running loss: 0.3163016140460968
# 50/159 - Running loss: 0.31503933668136597
# 60/159 - Running loss: 0.3705902397632599
# 70/159 - Running loss: 0.33409255743026733
# 80/159 - Running loss: 0.3748481571674347
# 90/159 - Running loss: 0.38372230529785156
# 100/159 - Running loss: 0.33756500482559204
# 110/159 - Running loss: 0.37117692828178406
# 120/159 - Running loss: 0.31513577699661255
# 130/159 - Running loss: 0.3143196403980255
# 140/159 - Running loss: 0.31517937779426575
# 150/159 - Running loss: 0.34089863300323486
# 11/40-Train loss:0.3378471218564975, Val loss:0.4199861434270751
# 11/40-Train acc:0.9789701257861635, Val acc:0.8844339622641509
# 0/159 - Running loss: 0.31400632858276367
# 10/159 - Running loss: 0.3143262565135956
# 20/159 - Running loss: 0.3283577859401703
# 30/159 - Running loss: 0.31542956829071045
# 40/159 - Running loss: 0.4428800940513611
# 50/159 - Running loss: 0.3679836392402649
# 60/159 - Running loss: 0.3171977996826172
# 70/159 - Running loss: 0.31347256898880005
# 80/159 - Running loss: 0.32471737265586853
# 90/159 - Running loss: 0.3444698452949524
# 100/159 - Running loss: 0.3144679069519043
# 110/159 - Running loss: 0.3188425600528717
# 120/159 - Running loss: 0.34415701031684875
# 130/159 - Running loss: 0.31341028213500977
# 140/159 - Running loss: 0.3177769184112549
# 150/159 - Running loss: 0.31831270456314087
# 12/40-Train loss:0.33418546307761715, Val loss:0.38847866317011276
# 12/40-Train acc:0.9829009433962265, Val acc:0.9215801886792453
# 0/159 - Running loss: 0.3221089839935303
# 10/159 - Running loss: 0.3370091915130615
# 20/159 - Running loss: 0.31327560544013977
# 30/159 - Running loss: 0.3756459057331085
# 40/159 - Running loss: 0.31590020656585693
# 50/159 - Running loss: 0.3208205997943878
# 60/159 - Running loss: 0.33925026655197144
# 70/159 - Running loss: 0.3136120140552521
# 80/159 - Running loss: 0.31339579820632935
# 90/159 - Running loss: 0.31442224979400635
# 100/159 - Running loss: 0.34422779083251953
# 110/159 - Running loss: 0.3406887948513031
# 120/159 - Running loss: 0.344726026058197
# 130/159 - Running loss: 0.341586172580719
# 140/159 - Running loss: 0.31540238857269287
# 150/159 - Running loss: 0.3587700426578522
# 13/40-Train loss:0.33286096277476857, Val loss:0.41423599506324194
# 13/40-Train acc:0.9856525157232704, Val acc:0.8873820754716981
# 0/159 - Running loss: 0.337289035320282
# 10/159 - Running loss: 0.31497472524642944
# 20/159 - Running loss: 0.33155524730682373
# 30/159 - Running loss: 0.3439289927482605
# 40/159 - Running loss: 0.3393406569957733
# 50/159 - Running loss: 0.31382355093955994
# 60/159 - Running loss: 0.3139372766017914
# 70/159 - Running loss: 0.31355640292167664
# 80/159 - Running loss: 0.3144308030605316
# 90/159 - Running loss: 0.3327986001968384
# 100/159 - Running loss: 0.33870989084243774
# 110/159 - Running loss: 0.3139953911304474
# 120/159 - Running loss: 0.3133326470851898
# 130/159 - Running loss: 0.3186284303665161
# 140/159 - Running loss: 0.3141065835952759
# 150/159 - Running loss: 0.354291170835495
# 14/40-Train loss:0.330981729727871, Val loss:0.43507925238249434
# 14/40-Train acc:0.9852594339622641, Val acc:0.8714622641509434
# 0/159 - Running loss: 0.3759363889694214
# 10/159 - Running loss: 0.3152555227279663
# 20/159 - Running loss: 0.3429804742336273
# 30/159 - Running loss: 0.31393590569496155
# 40/159 - Running loss: 0.3170596659183502
# 50/159 - Running loss: 0.3417099714279175
# 60/159 - Running loss: 0.3505423367023468
# 70/159 - Running loss: 0.33098888397216797
# 80/159 - Running loss: 0.3561896085739136
# 90/159 - Running loss: 0.32249975204467773
# 100/159 - Running loss: 0.3420369625091553
# 110/159 - Running loss: 0.3220829367637634
# 120/159 - Running loss: 0.31368985772132874
# 130/159 - Running loss: 0.3450062870979309
# 140/159 - Running loss: 0.3323885202407837
# 150/159 - Running loss: 0.33870944380760193
# 15/40-Train loss:0.330204039812088, Val loss:0.4270142485510628
# 15/40-Train acc:0.9868317610062893, Val acc:0.8773584905660378
# 0/159 - Running loss: 0.3300248384475708
# 10/159 - Running loss: 0.314076691865921
# 20/159 - Running loss: 0.37507352232933044
# 30/159 - Running loss: 0.313561350107193
# 40/159 - Running loss: 0.3207307755947113
# 50/159 - Running loss: 0.37558048963546753
# 60/159 - Running loss: 0.31335264444351196
# 70/159 - Running loss: 0.32688280940055847
# 80/159 - Running loss: 0.35185834765434265
# 90/159 - Running loss: 0.32648301124572754
# 100/159 - Running loss: 0.32157084345817566
# 110/159 - Running loss: 0.3719131350517273
# 120/159 - Running loss: 0.3668350577354431
# 130/159 - Running loss: 0.31517940759658813
# 140/159 - Running loss: 0.34461280703544617
# 150/159 - Running loss: 0.31367355585098267
# 16/40-Train loss:0.3321926323872692, Val loss:0.38916939778148
# 16/40-Train acc:0.9856525157232704, Val acc:0.9221698113207547
# 0/159 - Running loss: 0.32334399223327637
# 10/159 - Running loss: 0.31361836194992065
# 20/159 - Running loss: 0.34297776222229004
# 30/159 - Running loss: 0.31375646591186523
# 40/159 - Running loss: 0.34508833289146423
# 50/159 - Running loss: 0.3885025978088379
# 60/159 - Running loss: 0.34775152802467346
# 70/159 - Running loss: 0.316881388425827
# 80/159 - Running loss: 0.31389886140823364
# 90/159 - Running loss: 0.3136897385120392
# 100/159 - Running loss: 0.34444984793663025
# 110/159 - Running loss: 0.3484616279602051
# 120/159 - Running loss: 0.33056607842445374
# 130/159 - Running loss: 0.3406144380569458
# 140/159 - Running loss: 0.3162952661514282
# 150/159 - Running loss: 0.3980790972709656
# 17/40-Train loss:0.3313022235279563, Val loss:0.42201089240470024
# 17/40-Train acc:0.9876179245283019, Val acc:0.8874274310595065
# 0/159 - Running loss: 0.34825924038887024
# 10/159 - Running loss: 0.31587785482406616
# 20/159 - Running loss: 0.35346347093582153
# 30/159 - Running loss: 0.3137015402317047
# 40/159 - Running loss: 0.3150091767311096
# 50/159 - Running loss: 0.3149266839027405
# 60/159 - Running loss: 0.33700957894325256
# 70/159 - Running loss: 0.34523314237594604
# 80/159 - Running loss: 0.3387221693992615
# 90/159 - Running loss: 0.3451765775680542
# 100/159 - Running loss: 0.3140321969985962
# 110/159 - Running loss: 0.34377995133399963
# 120/159 - Running loss: 0.3198276162147522
# 130/159 - Running loss: 0.34457629919052124
# 140/159 - Running loss: 0.34549278020858765
# 150/159 - Running loss: 0.3192940950393677
# 18/40-Train loss:0.3327802670826702, Val loss:0.3878250628147485
# 18/40-Train acc:0.9852594339622641, Val acc:0.9242561683599418
# 0/159 - Running loss: 0.351910799741745
# 10/159 - Running loss: 0.31333470344543457
# 20/159 - Running loss: 0.35557618737220764
# 30/159 - Running loss: 0.3438798189163208
# 40/159 - Running loss: 0.3479200005531311
# 50/159 - Running loss: 0.31342706084251404
# 60/159 - Running loss: 0.3145085275173187
# 70/159 - Running loss: 0.3135589361190796
# 80/159 - Running loss: 0.3150879144668579
# 90/159 - Running loss: 0.3137992024421692
# 100/159 - Running loss: 0.3334686756134033
# 110/159 - Running loss: 0.3293093144893646
# 120/159 - Running loss: 0.31436946988105774
# 130/159 - Running loss: 0.31384754180908203
# 140/159 - Running loss: 0.3178789019584656
# 150/159 - Running loss: 0.3133780360221863
# 19/40-Train loss:0.33159033007591776, Val loss:0.4261687994003296
# 19/40-Train acc:0.987814465408805, Val acc:0.879127358490566
# 0/159 - Running loss: 0.31364187598228455
# 10/159 - Running loss: 0.3137812614440918
# 20/159 - Running loss: 0.3140407204627991
# 30/159 - Running loss: 0.3435172438621521
# 40/159 - Running loss: 0.31539186835289
# 50/159 - Running loss: 0.317267507314682
# 60/159 - Running loss: 0.31590571999549866
# 70/159 - Running loss: 0.3153116703033447
# 80/159 - Running loss: 0.32120051980018616
# 90/159 - Running loss: 0.3195982575416565
# 100/159 - Running loss: 0.31328073143959045
# 110/159 - Running loss: 0.3151445686817169
# 120/159 - Running loss: 0.3359401822090149
# 130/159 - Running loss: 0.34530460834503174
# 140/159 - Running loss: 0.35371360182762146
# 150/159 - Running loss: 0.33841028809547424
# 20/40-Train loss:0.3269884393275159, Val loss:0.39178283878092496
# 20/40-Train acc:0.9889937106918238, Val acc:0.918949564586357
# 0/159 - Running loss: 0.316420316696167
# 10/159 - Running loss: 0.3141268193721771
# 20/159 - Running loss: 0.31446635723114014
# 30/159 - Running loss: 0.34581100940704346
# 40/159 - Running loss: 0.31328627467155457
# 50/159 - Running loss: 0.3132646679878235
# 60/159 - Running loss: 0.3145047128200531
# 70/159 - Running loss: 0.3146587610244751
# 80/159 - Running loss: 0.31328487396240234
# 90/159 - Running loss: 0.31341513991355896
# 100/159 - Running loss: 0.31708112359046936
# 110/159 - Running loss: 0.3457212746143341
# 120/159 - Running loss: 0.3405010998249054
# 130/159 - Running loss: 0.3299886882305145
# 140/159 - Running loss: 0.3185824453830719
# 150/159 - Running loss: 0.36508074402809143
# 21/40-Train loss:0.3238191248485877, Val loss:0.3856218670899013
# 21/40-Train acc:0.9909591194968553, Val acc:0.9221698113207547
# 0/159 - Running loss: 0.3222917914390564
# 10/159 - Running loss: 0.34590476751327515
# 20/159 - Running loss: 0.3135035037994385
# 30/159 - Running loss: 0.31377726793289185
# 40/159 - Running loss: 0.3133624196052551
# 50/159 - Running loss: 0.31769824028015137
# 60/159 - Running loss: 0.3134329915046692
# 70/159 - Running loss: 0.3531772494316101
# 80/159 - Running loss: 0.3291340172290802
# 90/159 - Running loss: 0.3135150969028473
# 100/159 - Running loss: 0.31335213780403137
# 110/159 - Running loss: 0.3137057423591614
# 120/159 - Running loss: 0.31344330310821533
# 130/159 - Running loss: 0.31448766589164734
# 140/159 - Running loss: 0.3155839741230011
# 150/159 - Running loss: 0.3137127161026001
# 22/40-Train loss:0.322355662126961, Val loss:0.36502673351539755
# 22/40-Train acc:0.9927279874213837, Val acc:0.9524415820029027
# 0/159 - Running loss: 0.319894015789032
# 10/159 - Running loss: 0.31327924132347107
# 20/159 - Running loss: 0.31346794962882996
# 30/159 - Running loss: 0.31769293546676636
# 40/159 - Running loss: 0.3467470109462738
# 50/159 - Running loss: 0.3166249096393585
# 60/159 - Running loss: 0.31992918252944946
# 70/159 - Running loss: 0.31382158398628235
# 80/159 - Running loss: 0.31476402282714844
# 90/159 - Running loss: 0.3134594261646271
# 100/159 - Running loss: 0.3585328161716461
# 110/159 - Running loss: 0.3133605420589447
# 120/159 - Running loss: 0.3137882649898529
# 130/159 - Running loss: 0.3176526725292206
# 140/159 - Running loss: 0.32028689980506897
# 150/159 - Running loss: 0.3138904869556427
# 23/40-Train loss:0.3246232184973903, Val loss:0.3990639993604624
# 23/40-Train acc:0.9915487421383647, Val acc:0.9109669811320755
# 0/159 - Running loss: 0.3155972361564636
# 10/159 - Running loss: 0.3134877681732178
# 20/159 - Running loss: 0.3134802281856537
# 30/159 - Running loss: 0.3138030767440796
# 40/159 - Running loss: 0.3132830560207367
# 50/159 - Running loss: 0.3132719099521637
# 60/159 - Running loss: 0.31766605377197266
# 70/159 - Running loss: 0.3147217035293579
# 80/159 - Running loss: 0.31453996896743774
# 90/159 - Running loss: 0.3171749413013458
# 100/159 - Running loss: 0.3155726492404938
# 110/159 - Running loss: 0.31516972184181213
# 120/159 - Running loss: 0.31379637122154236
# 130/159 - Running loss: 0.3134428858757019
# 140/159 - Running loss: 0.3136318027973175
# 150/159 - Running loss: 0.3599526584148407
# 24/40-Train loss:0.32084090792158115, Val loss:0.42858272734678016
# 24/40-Train acc:0.9948899371069182, Val acc:0.875
# 0/159 - Running loss: 0.35200920701026917
# 10/159 - Running loss: 0.3186885118484497
# 20/159 - Running loss: 0.3314877450466156
# 30/159 - Running loss: 0.3606380522251129
# 40/159 - Running loss: 0.31376874446868896
# 50/159 - Running loss: 0.3166448175907135
# 60/159 - Running loss: 0.34456387162208557
# 70/159 - Running loss: 0.34464144706726074
# 80/159 - Running loss: 0.31352245807647705
# 90/159 - Running loss: 0.31371814012527466
# 100/159 - Running loss: 0.3138124346733093
# 110/159 - Running loss: 0.3382870852947235
# 120/159 - Running loss: 0.3466567099094391
# 130/159 - Running loss: 0.34627434611320496
# 140/159 - Running loss: 0.3454118072986603
# 150/159 - Running loss: 0.34430307149887085
# 25/40-Train loss:0.3230426916911167, Val loss:0.38184153190198933
# 25/40-Train acc:0.9929245283018868, Val acc:0.9280660377358491
# 0/159 - Running loss: 0.3139168322086334
# 10/159 - Running loss: 0.31414756178855896
# 20/159 - Running loss: 0.31524658203125
# 30/159 - Running loss: 0.3136935532093048
# 40/159 - Running loss: 0.3135468363761902
# 50/159 - Running loss: 0.34059372544288635
# 60/159 - Running loss: 0.31356579065322876
# 70/159 - Running loss: 0.32487165927886963
# 80/159 - Running loss: 0.3138834238052368
# 90/159 - Running loss: 0.344596803188324
# 100/159 - Running loss: 0.37302684783935547
# 110/159 - Running loss: 0.3172288239002228
# 120/159 - Running loss: 0.3140608072280884
# 130/159 - Running loss: 0.31480273604393005
# 140/159 - Running loss: 0.3133218288421631
# 150/159 - Running loss: 0.31354838609695435
# 26/40-Train loss:0.31964949504384454, Val loss:0.3997832626666663
# 26/40-Train acc:0.9952830188679245, Val acc:0.9086084905660378
# 0/159 - Running loss: 0.31352466344833374
# 10/159 - Running loss: 0.31328147649765015
# 20/159 - Running loss: 0.3134503960609436
# 30/159 - Running loss: 0.34258735179901123
# 40/159 - Running loss: 0.31390494108200073
# 50/159 - Running loss: 0.31345710158348083
# 60/159 - Running loss: 0.32039371132850647
# 70/159 - Running loss: 0.3445677161216736
# 80/159 - Running loss: 0.31327366828918457
# 90/159 - Running loss: 0.313544362783432
# 100/159 - Running loss: 0.31329482793807983
# 110/159 - Running loss: 0.31442639231681824
# 120/159 - Running loss: 0.3166678547859192
# 130/159 - Running loss: 0.31504371762275696
# 140/159 - Running loss: 0.333539217710495
# 150/159 - Running loss: 0.31329530477523804
# 27/40-Train loss:0.3199670457240171, Val loss:0.3862939909943994
# 27/40-Train acc:0.9950864779874213, Val acc:0.9248457910014514
# 0/159 - Running loss: 0.3140191435813904
# 10/159 - Running loss: 0.3162957429885864
# 20/159 - Running loss: 0.3445654511451721
# 30/159 - Running loss: 0.31326353549957275
# 40/159 - Running loss: 0.33489832282066345
# 50/159 - Running loss: 0.31461217999458313
# 60/159 - Running loss: 0.31326550245285034
# 70/159 - Running loss: 0.3136448860168457
# 80/159 - Running loss: 0.3133241534233093
# 90/159 - Running loss: 0.31331777572631836
# 100/159 - Running loss: 0.3133962154388428
# 110/159 - Running loss: 0.3132963180541992
# 120/159 - Running loss: 0.3134690821170807
# 130/159 - Running loss: 0.3132796883583069
# 140/159 - Running loss: 0.3691280782222748
# 150/159 - Running loss: 0.3133421540260315
# 28/40-Train loss:0.31901981976796995, Val loss:0.4143903874001413
# 28/40-Train acc:0.9956761006289309, Val acc:0.8909198113207547
# 0/159 - Running loss: 0.3153829872608185
# 10/159 - Running loss: 0.31332260370254517
# 20/159 - Running loss: 0.3152783513069153
# 30/159 - Running loss: 0.34385907649993896
# 40/159 - Running loss: 0.31332817673683167
# 50/159 - Running loss: 0.31345149874687195
# 60/159 - Running loss: 0.31329694390296936
# 70/159 - Running loss: 0.3132686913013458
# 80/159 - Running loss: 0.3132753074169159
# 90/159 - Running loss: 0.3133869469165802
# 100/159 - Running loss: 0.3208717703819275
# 110/159 - Running loss: 0.3133048713207245
# 120/159 - Running loss: 0.3139643669128418
# 130/159 - Running loss: 0.31334352493286133
# 140/159 - Running loss: 0.3138693869113922
# 150/159 - Running loss: 0.31339654326438904
# 29/40-Train loss:0.31807939848809874, Val loss:0.4040126665583197
# 29/40-Train acc:0.9960691823899371, Val acc:0.9056603773584906
# 0/159 - Running loss: 0.3134051263332367
# 10/159 - Running loss: 0.3134773075580597
# 20/159 - Running loss: 0.3133572041988373
# 30/159 - Running loss: 0.31369006633758545
# 40/159 - Running loss: 0.313754677772522
# 50/159 - Running loss: 0.31405267119407654
# 60/159 - Running loss: 0.40732505917549133
# 70/159 - Running loss: 0.3335455060005188
# 80/159 - Running loss: 0.3133382797241211
# 90/159 - Running loss: 0.31334882974624634
# 100/159 - Running loss: 0.3133965730667114
# 110/159 - Running loss: 0.31326866149902344
# 120/159 - Running loss: 0.3134382367134094
# 130/159 - Running loss: 0.32752320170402527
# 140/159 - Running loss: 0.3296051621437073
# 150/159 - Running loss: 0.34466198086738586
# 30/40-Train loss:0.319200021665801, Val loss:0.42309782808681706
# 30/40-Train acc:0.9954795597484277, Val acc:0.8826650943396226
# 0/159 - Running loss: 0.31327345967292786
# 10/159 - Running loss: 0.31333085894584656
# 20/159 - Running loss: 0.31356993317604065
# 30/159 - Running loss: 0.31330129504203796
# 40/159 - Running loss: 0.3133993148803711
# 50/159 - Running loss: 0.3132769763469696
# 60/159 - Running loss: 0.3151834309101105
# 70/159 - Running loss: 0.3482699692249298
# 80/159 - Running loss: 0.31326571106910706
# 90/159 - Running loss: 0.31326815485954285
# 100/159 - Running loss: 0.3132736384868622
# 110/159 - Running loss: 0.3133341073989868
# 120/159 - Running loss: 0.34488049149513245
# 130/159 - Running loss: 0.3457019031047821
# 140/159 - Running loss: 0.31345170736312866
# 150/159 - Running loss: 0.3135809004306793
# 31/40-Train loss:0.31778537383619343, Val loss:0.3852843574757846
# 31/40-Train acc:0.9962657232704403, Val acc:0.9245283018867925
# 0/159 - Running loss: 0.3133327066898346
# 10/159 - Running loss: 0.3132834732532501
# 20/159 - Running loss: 0.313283234834671
# 30/159 - Running loss: 0.3134533166885376
# 40/159 - Running loss: 0.31330007314682007
# 50/159 - Running loss: 0.3133291006088257
# 60/159 - Running loss: 0.3135974407196045
# 70/159 - Running loss: 0.31326794624328613
# 80/159 - Running loss: 0.3133070170879364
# 90/159 - Running loss: 0.31327587366104126
# 100/159 - Running loss: 0.3133009076118469
# 110/159 - Running loss: 0.31326809525489807
# 120/159 - Running loss: 0.3133300542831421
# 130/159 - Running loss: 0.31326550245285034
# 140/159 - Running loss: 0.31326472759246826
# 150/159 - Running loss: 0.31333500146865845
# 32/40-Train loss:0.31705779605691536, Val loss:0.39268111957694
# 32/40-Train acc:0.9968553459119497, Val acc:0.9168632075471698
# 0/159 - Running loss: 0.3132628798484802
# 10/159 - Running loss: 0.3151446282863617
# 20/159 - Running loss: 0.319262832403183
# 30/159 - Running loss: 0.3132692277431488
# 40/159 - Running loss: 0.3132804334163666
# 50/159 - Running loss: 0.31326454877853394
# 60/159 - Running loss: 0.3138083517551422
# 70/159 - Running loss: 0.3133469521999359
# 80/159 - Running loss: 0.3132755160331726
# 90/159 - Running loss: 0.3133017122745514
# 100/159 - Running loss: 0.31326907873153687
# 110/159 - Running loss: 0.3138602674007416
# 120/159 - Running loss: 0.3132990002632141
# 130/159 - Running loss: 0.3132755756378174
# 140/159 - Running loss: 0.313392698764801
# 150/159 - Running loss: 0.3134063184261322
# 33/40-Train loss:0.31632880875899355, Val loss:0.3904183473227159
# 33/40-Train acc:0.997248427672956, Val acc:0.9174528301886793
# 0/159 - Running loss: 0.31336626410484314
# 10/159 - Running loss: 0.3132912814617157
# 20/159 - Running loss: 0.313356876373291
# 30/159 - Running loss: 0.31346064805984497
# 40/159 - Running loss: 0.3132733106613159
# 50/159 - Running loss: 0.3133223056793213
# 60/159 - Running loss: 0.3134213387966156
# 70/159 - Running loss: 0.31326359510421753
# 80/159 - Running loss: 0.31342849135398865
# 90/159 - Running loss: 0.3132633864879608
# 100/159 - Running loss: 0.3132704794406891
# 110/159 - Running loss: 0.31327685713768005
# 120/159 - Running loss: 0.3133793771266937
# 130/159 - Running loss: 0.31336453557014465
# 140/159 - Running loss: 0.31326356530189514
# 150/159 - Running loss: 0.34451767802238464
# 34/40-Train loss:0.3163141298968837, Val loss:0.3709656483722183
# 34/40-Train acc:0.9970518867924528, Val acc:0.9404481132075472
# 0/159 - Running loss: 0.34534135460853577
# 10/159 - Running loss: 0.31366705894470215
# 20/159 - Running loss: 0.31331491470336914
# 30/159 - Running loss: 0.31326913833618164
# 40/159 - Running loss: 0.3132789134979248
# 50/159 - Running loss: 0.3138280510902405
# 60/159 - Running loss: 0.3133845627307892
# 70/159 - Running loss: 0.3133441209793091
# 80/159 - Running loss: 0.31339365243911743
# 90/159 - Running loss: 0.3133586049079895
# 100/159 - Running loss: 0.31326764822006226
# 110/159 - Running loss: 0.31329089403152466
# 120/159 - Running loss: 0.3132861852645874
# 130/159 - Running loss: 0.3132978677749634
# 140/159 - Running loss: 0.3133799135684967
# 150/159 - Running loss: 0.31327059864997864
# 35/40-Train loss:0.31635317674972724, Val loss:0.3872808229248479
# 35/40-Train acc:0.9970518867924528, Val acc:0.9215801886792453
# 0/159 - Running loss: 0.3132827877998352
# 10/159 - Running loss: 0.3132629096508026
# 20/159 - Running loss: 0.31355953216552734
# 30/159 - Running loss: 0.31402498483657837
# 40/159 - Running loss: 0.34407320618629456
# 50/159 - Running loss: 0.31328368186950684
# 60/159 - Running loss: 0.31328219175338745
# 70/159 - Running loss: 0.31327691674232483
# 80/159 - Running loss: 0.31327009201049805
# 90/159 - Running loss: 0.3134375214576721
# 100/159 - Running loss: 0.3132666051387787
# 110/159 - Running loss: 0.31331926584243774
# 120/159 - Running loss: 0.31331855058670044
# 130/159 - Running loss: 0.31331074237823486
# 140/159 - Running loss: 0.3133096992969513
# 150/159 - Running loss: 0.31326788663864136
# 36/40-Train loss:0.3162679672241211, Val loss:0.38192052886171163
# 36/40-Train acc:0.9970518867924528, Val acc:0.9286556603773585
# 0/159 - Running loss: 0.3133559226989746
# 10/159 - Running loss: 0.31326380372047424
# 20/159 - Running loss: 0.3133654296398163
# 30/159 - Running loss: 0.313353031873703
# 40/159 - Running loss: 0.3133271634578705
# 50/159 - Running loss: 0.31326594948768616
# 60/159 - Running loss: 0.3132682740688324
# 70/159 - Running loss: 0.31332528591156006
# 80/159 - Running loss: 0.3132658898830414
# 90/159 - Running loss: 0.3446148633956909
# 100/159 - Running loss: 0.31326988339424133
# 110/159 - Running loss: 0.313283771276474
# 120/159 - Running loss: 0.31336820125579834
# 130/159 - Running loss: 0.313276469707489
# 140/159 - Running loss: 0.31327977776527405
# 150/159 - Running loss: 0.37584295868873596
# 37/40-Train loss:0.3162509114862238, Val loss:0.3880363371012346
# 37/40-Train acc:0.9970518867924528, Val acc:0.9204009433962265
# 0/159 - Running loss: 0.31327319145202637
# 10/159 - Running loss: 0.3132668733596802
# 20/159 - Running loss: 0.31327906250953674
# 30/159 - Running loss: 0.3133215010166168
# 40/159 - Running loss: 0.31330037117004395
# 50/159 - Running loss: 0.31327539682388306
# 60/159 - Running loss: 0.31331902742385864
# 70/159 - Running loss: 0.3132690191268921
# 80/159 - Running loss: 0.31334057450294495
# 90/159 - Running loss: 0.3133082091808319
# 100/159 - Running loss: 0.313312292098999
# 110/159 - Running loss: 0.31330928206443787
# 120/159 - Running loss: 0.31336042284965515
# 130/159 - Running loss: 0.3134888708591461
# 140/159 - Running loss: 0.313274085521698
# 150/159 - Running loss: 0.31337621808052063
# 38/40-Train loss:0.31605428232336946, Val loss:0.3829383169705013
# 38/40-Train acc:0.997248427672956, Val acc:0.9268867924528302
# 0/159 - Running loss: 0.3135699927806854
# 10/159 - Running loss: 0.3132625222206116
# 20/159 - Running loss: 0.3132929801940918
# 30/159 - Running loss: 0.3132847845554352
# 40/159 - Running loss: 0.31329771876335144
# 50/159 - Running loss: 0.3135330379009247
# 60/159 - Running loss: 0.313268780708313
# 70/159 - Running loss: 0.31329935789108276
# 80/159 - Running loss: 0.3132666051387787
# 90/159 - Running loss: 0.31327149271965027
# 100/159 - Running loss: 0.31352952122688293
# 110/159 - Running loss: 0.3132862150669098
# 120/159 - Running loss: 0.3132626414299011
# 130/159 - Running loss: 0.31334683299064636
# 140/159 - Running loss: 0.31327611207962036
# 150/159 - Running loss: 0.31329092383384705
# 39/40-Train loss:0.31623675350872976, Val loss:0.3852847724590661
# 39/40-Train acc:0.9970518867924528, Val acc:0.9245283018867925
# 0/159 - Running loss: 0.3132902979850769
# 10/159 - Running loss: 0.31326985359191895
# 20/159 - Running loss: 0.3132624328136444
# 30/159 - Running loss: 0.3132990598678589
# 40/159 - Running loss: 0.3134910762310028
# 50/159 - Running loss: 0.31327730417251587
# 60/159 - Running loss: 0.31326380372047424
# 70/159 - Running loss: 0.3132891058921814
# 80/159 - Running loss: 0.31343042850494385
# 90/159 - Running loss: 0.3437054455280304
# 100/159 - Running loss: 0.31329545378685
# 110/159 - Running loss: 0.3134359121322632
# 120/159 - Running loss: 0.31333884596824646
# 130/159 - Running loss: 0.313264936208725
# 140/159 - Running loss: 0.34697386622428894
# 150/159 - Running loss: 0.31327465176582336
# 40/40-Train loss:0.3163067647870981, Val loss:0.40068853801151494
# 40/40-Train acc:0.997248427672956, Val acc:0.9038915094339622

# %%
plt.title('VGG19_avg1_CELU_epoch40_Loss')
plt.plot(train_loss, label='train')
plt.plot(val_loss, label='val')
plt.xlabel('EPOCH')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.show()

# %%
plt.title('VGG19_avg1_CELU_epoch40_Accuracy')
plt.plot(train_acc, label='train')
plt.plot(val_acc, label='val')
plt.xlabel('EPOCH')
plt.ylabel('Accuracy')
plt.legend(loc='upper right')
plt.show()
#plt.annotate('annotate',xy=(2,10),xytext=(5,20),arrowprops={'color':'green'})

# %%
-

# %%
num_epochs = 20

best_acc = 0.0
train_loss, train_acc = [], []
val_loss, val_acc = [], []

for epoch in range(num_epochs):
    losses, accuracies = train_one_epoch(dataloaders, model, optimizer, loss_func, device)
    train_loss.append(losses['train'])
    train_acc.append(accuracies['train'])
    val_loss.append(losses['val'])
    val_acc.append(accuracies['val'])
    
    print(f"{epoch+1}/{num_epochs}-Train loss:{losses['train']}, Val loss:{losses['val']}")
    print(f"{epoch+1}/{num_epochs}-Train acc:{accuracies['train']}, Val acc:{accuracies['val']}")
    
    if accuracies['val'] > best_acc:
        best_acc = accuracies['val']
        torch.save(model.state_dict(), f"model_{epoch}.pth")

# %%
----

# %%
# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim
from torchvision import models

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
pure_vgg19 = models.vgg19(pretrained=True)

# %%
pure_vgg19 = pure_vgg19.to(device)

# %%
summary(pure_vgg19, (3,224,224), batch_size=32, device='cuda')
# total parameter즉, parameter size가 줄었다.

# %%
pure_vgg19.classifier = nn.Sequential(
    nn.Flatten(),
    nn.Linear(25088, 4096),
    nn.ReLU(),
    nn.Dropout(0.1),
    nn.Linear(4096, 1000),
    nn.ReLU(),
    nn.Dropout(0.1), #네트워크 가중치 편향을 막기 위해 사용
    nn.Linear(1000,2),
    nn.Sigmoid()
)

# %%
'''
pure_vgg19.classifier[3] = nn.Linear(in_features=4096, out_features=1000)
pure_vgg19.classifier[6] = nn.Linear(in_features=1000, out_features=2)
pure_vgg19.classifier[7] = nn.Sigmoid()
'''

# %%
pure_vgg19

# %%
pure_vgg19 = pure_vgg19.to(device)

# %%
summary(pure_vgg19, (3,224,224), batch_size=32)

# %%
device = torch.device('cuda')

# %%
model = pure_vgg19

# %%
@torch.no_grad()
def get_accuracy(image, target, model):
    batch_size = image.shape[0] #이미지에서 batch크기를 계산을 하고 이미지를 연산을 해서 output값에 넣어준다
    prediction = model(image) # prediction값은 (batch_size, num_classes)이다. 
    #예를들어 이때 각 class마다 [B, 0]: 0,1, [B,1]:0.2, [B,2]:0.7
    _, pred_label = torch.max(prediction, dim=1) # dimension 1을 기준으로 max값을 구한다.위의 경우에서 (B,1) -> pred_label =2
    is_correct = (pred_label == target) #pred_label과 target을 매칭하여 True/ False를 반환
    accuracy = is_correct.cpu().numpy().sum() / batch_size #True, False를 모두 더하면 false는0 true는 1로 대변이 된다. 이것을 batch_size로 나눈다.
    return accuracy

#accuracy를 함수로 작성한 이유는 매 iteration, epoch에 train과 validation에 대해서 매번 accuracy를 연산을 하고, 개선되는 과정을 살펴 볼것이기 때문에 이 함수가 반복적으로 호출되기 위해 함수를짯다.
#accuracy가 계산되는 과정에서는 backward과정이 필요없기 때문에 decorater까지 넣어주어 model의 파라미터에 대해서 gradient update 과정을 꺼준다.

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

train_data_dir = 'D:/covid/train/'
val_data_dir = 'D:/covid/test/'
dataloaders = build_dataloader(train_data_dir, val_data_dir)
model = pure_vgg19.to(device)
loss_func = nn.CrossEntropyLoss(reduction='mean')
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)

# %%
# 한번 iteration할때 train과 validation이 동작을 한다. 한번 epoch할떄 train한번, epoch한번 돌아서 loss를 반환을 하고 그 loss를 토대로 overfitting이 되는지 한단한다.
def train_one_epoch(dataloader, model, optimizer, loss_function, device):
    losses = {}
    accuracies = {}
    
    for phase in["train", "val"]: 
        running_loss = 0.0
        running_correct = 0.0
        #중간 중간 loss를 확인하기 위해서 필요하다. 중간중간에 running loss를 받아와서 print문으로 출력해서 잘 학습이 되는지 확인할 수 있게한다.
        
        if phase == "train":
            model.train()
        else:
            model.eval() 
            #모델내 btach normalizization나 dropout등을 activation 할지말지 구별한다. 즉, train과 validation set에서 다르게 작동하는 layer가 있기 때문에 이를 구별하기위해 사용한다.
            
        for index, batch in enumerate(dataloader[phase]): #dataloaders를 phase에 맞게 불러오고 index값과 batch형태로 iterative하게 가져온다. batch는 엄밀히 말하면 mini_batch다.
            image = batch[0].to(device) #image 
            label = batch[1].squeeze(dim=1).to(device) #label 위에선 class id normal이면 0 covid면1
            
            with torch.set_grad_enabled(phase =="train"):
                prediction = model(image)
                loss = loss_func(prediction, label)
                
                optimizer.zero_grad()
                
                if phase == "train":
                    #optimizer.zero_grad() #loss를 계산하고, loss에 대해서 optimizer의 weight값을 업데이트 할때, optimizer에 zero_grad를 안해주면 미분의 누적값들이 계속 생기게 된다. 따라서 학습이 원하는 방향으로 진행이 되지 않을수 있다. 그렇기 때문에 loss를 기반으로 optimizer를 수행하기전에 미분함수의 파라미터에 들어있는 모든 gradient를 0으로 만들어주고 그다음 loss에 해당하는 파라미터의 기울기 값을 다시 갱신을 해주고 다시 optimizer를 수행한다.
                    loss.backward() #loss가 구해지면 model의 파라미터의 gradient를 추적할수 있는 기능이 있는데 loss.backward()를 통해 loss값에 관련이 있는 모든 model의 파라미터의 미분값이 업데이트 되게 된다.
                    optimizer.step() #이 미분값을 optimizer에 전달하게되고, 가중치를 미리 설정한 수식에 따라서 가중치와 learning rate를 토대로 모델의 weight값을 갱신하게 된다. loss를 가지고 optimizer을 수행한다.
                    
            running_loss += loss.item() #loss 값의 value만 받아서 아까 설정한 running_loss에 누적을 시켜준다.
            running_correct += get_accuracy(image, label, model)
                            
                #index 10번 주기의 간격으로 running loss를 출력을 해라라는 의미다.
            if phase == "train":
                if index % 10 == 0:
                    print(f"{index}/{len(dataloaders['train'])} - Running loss: {loss.item()}")#running_loss의 값은 최종적으로 dataloader의 개수(batch크기의 평균한 값)을 계산하고 각 phase의 key값에 전달해준다.
                    
        losses[phase] = running_loss / len(dataloader[phase])
        accuracies[phase] = running_correct / len(dataloader[phase])
    return losses, accuracies

# %%
--

# %%
num_epochs = 10

best_acc = 0.0
train_loss, train_acc = [], []
val_loss, val_acc = [], []

for epoch in range(num_epochs):
    losses, accuracies = train_one_epoch(dataloaders, model, optimizer, loss_func, device)
    train_loss.append(losses['train'])
    train_acc.append(accuracies['train'])
    val_loss.append(losses['val'])
    val_acc.append(accuracies['val'])
    
    print(f"{epoch+1}/{num_epochs}-Train loss:{losses['train']}, Val loss:{losses['val']}")
    print(f"{epoch+1}/{num_epochs}-Train acc:{accuracies['train']}, Val acc:{accuracies['val']}")
    
    if accuracies['val'] > best_acc:
        best_acc = accuracies['val']
        torch.save(model.state_dict(), f"vgg_model_{epoch}.pth")

# %% [markdown]
# # Resnet

# %%
res = models.resnet50(pretrained=True)

# %%
res

# %%
res = res.to(device)

# %%
summary(res, (3,224,224))

# %%
res152 = models.resnet152()

# %%
res152

# %%
res152 = res152.to(device)

# %%
summary(res152, (32,3,224,224))

# %%
summary(res152, (3,224,224), batch_size=32)

# %%
from torchsummaryX import summary

# %%
res152 = models.resnet152()

# %%
summary(res152, torch.zeros((3,3,224,224)))

# %%
from torchinfo import summary

# %%
summary(res152, (32,3,224,224))

# %% [markdown]
# #  Densenet
#
# : torchvision.models에서 가져온 densenet은 torchvision이 되지 않는다. 이때 우리는 torchsummaryX와 torchinfo를사용할 수 있다.
# torchsummaryX는 to.device를 하면 적용되지 않는다.(모델을 cuda에 올려놓으면 안된다)
# torchimfo는 상관없이 적용 가능하다.
#
# https://deep-learning-study.tistory.com/545
#
# https://hoya012.github.io/blog/DenseNet-Tutorial-2/

# %%
model2 = models.densenet121(pretrained=True)

# %%
model2

# %%
model2 = model2.to(device)

# %%
summary(model2, (3,224,224), batch_size=32)

# %%
from torchsummaryX import summary

# %%
model2 = models.densenet121(pretrained=True)

# %%
summary(model2, torch.zeros((3,3,224,224)))

# %%
#pip install torchinfo

# %%
from torchinfo import summary

# %%
model2 = model2.to(device)

# %%
summary(model2, (32,3,224,224))

# %%
# model
import torch
import torch.nn as nn
import torch.nn.functional as F
from torchsummary import summary
from torch import optim

# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy

# %%
import torch.nn as nn

# %%
# DenseNet BottleNeck
class BottleNeck(nn.Module):
    def __init__(self, in_channels, growth_rate):
        super().__init__()
        inner_channels = 4 * growth_rate

        self.residual = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, inner_channels, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(inner_channels),
            nn.ReLU(),
            nn.Conv2d(inner_channels, growth_rate, 3, stride=1, padding=1, bias=False)
        )

        self.shortcut = nn.Sequential()

    def forward(self, x):
        return torch.cat([self.shortcut(x), self.residual(x)], 1)

# %%
# Transition Block: reduce feature map size and number of channels
class Transition(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()

        self.down_sample = nn.Sequential(
            nn.BatchNorm2d(in_channels),
            nn.ReLU(),
            nn.Conv2d(in_channels, out_channels, 1, stride=1, padding=0, bias=False),
            nn.AvgPool2d(2, stride=2)
        )

    def forward(self, x):
        return self.down_sample(x)

# %%
# DenseNet
class DenseNet(nn.Module):
    def __init__(self, nblocks, growth_rate=12, reduction=0.5, num_classes=2, init_weights=True):
        super().__init__()

        self.growth_rate = growth_rate
        inner_channels = 2 * growth_rate # output channels of conv1 before entering Dense Block

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, inner_channels, 7, stride=2, padding=3),
            nn.MaxPool2d(3, 2, padding=1)
        )

        self.features = nn.Sequential()

        for i in range(len(nblocks)-1):
            self.features.add_module('dense_block_{}'.format(i), self._make_dense_block(nblocks[i], inner_channels))
            inner_channels += growth_rate * nblocks[i]
            out_channels = int(reduction * inner_channels)
            self.features.add_module('transition_layer_{}'.format(i), Transition(inner_channels, out_channels))
            inner_channels = out_channels 
        
        self.features.add_module('dense_block_{}'.format(len(nblocks)-1), self._make_dense_block(nblocks[len(nblocks)-1], inner_channels))
        inner_channels += growth_rate * nblocks[len(nblocks)-1]
        self.features.add_module('bn', nn.BatchNorm2d(inner_channels))
        self.features.add_module('relu', nn.ReLU())

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(inner_channels, num_classes)

        # weight initialization
        if init_weights:
            self._initialize_weights()
    
    def forward(self, x):
        x = self.conv1(x)
        x = self.features(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    def _make_dense_block(self, nblock, inner_channels):
        dense_block = nn.Sequential()
        for i in range(nblock):
            dense_block.add_module('bottle_neck_layer_{}'.format(i), BottleNeck(inner_channels, self.growth_rate))
            inner_channels += self.growth_rate
        return dense_block

    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def DenseNet_121():
    return DenseNet([6, 12, 24, 6])

# %%
DenseNet_121()

# %%
# check model
x = torch.randn(3, 3, 224, 224)
model3 = DenseNet_121()
output = model3(x)
print(output.size())

# %%
# print model summary
model3 = model3.to(device)
summary(model3, (3, 224, 224), batch_size=32)

# %%
# print model summary
model = model.to(device)
summary(model, (3, 224, 224))

# %%
# print model summary
model = model.to(device)
summary(model, (3, 224, 224), batch_size=32)

# %%
# print model summary
model3 = model3.to(device)
summary(model3, (3, 224, 224))

# %%
# print model summary
model3 = model3.to(device)
summary(model3, (3, 224, 224), batch_size=32)

# %%
================================================================
Total params: 788,162
Trainable params: 788,162
Non-trainable params: 0
----------------------------------------------------------------
Input size (MB): 0.05
Forward/backward pass size (MB): 10.71
Params size (MB): 3.01
Estimated Total Size (MB): 13.77
----------------------------------------------------------------
